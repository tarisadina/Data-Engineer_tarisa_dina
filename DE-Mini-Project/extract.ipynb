# %% [markdown]
# # EXTRACT CSV

# %%
pip install beautifulsoup4
# Out:
# ...
#
# ...
# WARNING: You are using pip version 21.2.4; however, version 24.0 is available.
# You should consider upgrading via the 'C:\Users\hello\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.4; however, version 24.0 is available.
# You should consider upgrading via the 'C:\Users\hello\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.4; however, version 24.0 is available.
# You should consider upgrading via the 'C:\Users\hello\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests
import sqlite3

# %% [markdown]
# Extract CSV

# %% [markdown]
# # ELECTRICITY_ACCESS_PERCENT

# %% [markdown]
# EXTRACT

# %%
electricity = pd.read_csv("E:\DE-Mini-Project\data_source\electricity_access_percent.csv")
print(electricity)
# Out:
#      Country Name Country Code                           Indicator Name  \
# 0           Aruba          ABW  Access to electricity (% of population)
# 1     Afghanistan          AFG  Access to electricity (% of population)
# 2          Angola          AGO  Access to electricity (% of population)
# 3         Albania          ALB  Access to electricity (% of population)
# 4         Andorra          AND  Access to electricity (% of population)
# ..            ...          ...                                      ...
# 259        Kosovo          XKX  Access to electricity (% of population)
# 260   Yemen, Rep.          YEM  Access to electricity (% of population)
# 261  South Africa          ZAF  Access to electricity (% of population)
# 262        Zambia          ZMB  Access to electricity (% of population)
# 263      Zimbabwe          ZWE  Access to electricity (% of population)
#
#      Indicator Code  1960  1961  1962  1963  1964  1965  ...        2009  \
# ...

# %% [markdown]
# MISSING VALUE

# %%
data_electricity_check_missing = electricity.isnull().sum()

print("Mengecek data yang hilang\n")
print(data_electricity_check_missing)
# Out:
# Mengecek data yang hilang
#
# Country Name        0
# Country Code        0
# Indicator Name      0
# Indicator Code      0
# 1960              264
#                  ...
# 2014                3
# 2015                3
# 2016                3
# 2017              264
# Unnamed: 62       264
# Length: 63, dtype: int64

# %% [markdown]
# CLEANING DATA

# %%
electricity_cleaned = electricity.dropna(axis=1, how='all')

print("Setelah mengecek data yang hilang")
print(electricity_cleaned)
# Out:
# Setelah mengecek data yang hilang
#      Country Name Country Code                           Indicator Name  \
# 0           Aruba          ABW  Access to electricity (% of population)
# 1     Afghanistan          AFG  Access to electricity (% of population)
# 2          Angola          AGO  Access to electricity (% of population)
# 3         Albania          ALB  Access to electricity (% of population)
# 4         Andorra          AND  Access to electricity (% of population)
# ..            ...          ...                                      ...
# 259        Kosovo          XKX  Access to electricity (% of population)
# 260   Yemen, Rep.          YEM  Access to electricity (% of population)
# 261  South Africa          ZAF  Access to electricity (% of population)
# 262        Zambia          ZMB  Access to electricity (% of population)
# 263      Zimbabwe          ZWE  Access to electricity (% of population)
#
# ...

# %%
pip install scikit-learn
# Out:
# ...
#
# ...
# WARNING: You are using pip version 21.2.4; however, version 24.0 is available.
# You should consider upgrading via the 'C:\Users\hello\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %% [markdown]
# DATA DUPLICATE

# %%
electricity_duplicate = electricity_cleaned.drop_duplicates()

print(electricity_duplicate)

electricity_duplicate.to_csv("data_clean/electricity_clean.csv", index=False)
# Out:
#      Country Name Country Code                           Indicator Name  \
# 0           Aruba          ABW  Access to electricity (% of population)
# 1     Afghanistan          AFG  Access to electricity (% of population)
# 2          Angola          AGO  Access to electricity (% of population)
# 3         Albania          ALB  Access to electricity (% of population)
# 4         Andorra          AND  Access to electricity (% of population)
# ..            ...          ...                                      ...
# 259        Kosovo          XKX  Access to electricity (% of population)
# 260   Yemen, Rep.          YEM  Access to electricity (% of population)
# 261  South Africa          ZAF  Access to electricity (% of population)
# 262        Zambia          ZMB  Access to electricity (% of population)
# 263      Zimbabwe          ZWE  Access to electricity (% of population)
#
#      Indicator Code        1990        1991        1992        1993  \
# ...

# %% [markdown]
# # GDP_DATA

# %% [markdown]
# EXTRACT

# %%
gdp_data = pd.read_csv("E:\DE-Mini-Project\data_source\gdp_data.csv")
gdp_data
# Out:
#      Country Name Country Code     Indicator Name  Indicator Code  \
# 0           Aruba          ABW  GDP (current US$)  NY.GDP.MKTP.CD
# 1     Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD
# 2          Angola          AGO  GDP (current US$)  NY.GDP.MKTP.CD
# 3         Albania          ALB  GDP (current US$)  NY.GDP.MKTP.CD
# 4         Andorra          AND  GDP (current US$)  NY.GDP.MKTP.CD
# ..            ...          ...                ...             ...
# 259        Kosovo          XKX  GDP (current US$)  NY.GDP.MKTP.CD
# 260   Yemen, Rep.          YEM  GDP (current US$)  NY.GDP.MKTP.CD
# 261  South Africa          ZAF  GDP (current US$)  NY.GDP.MKTP.CD
# 262        Zambia          ZMB  GDP (current US$)  NY.GDP.MKTP.CD
# 263      Zimbabwe          ZWE  GDP (current US$)  NY.GDP.MKTP.CD
#
#              1960          1961          1962          1963          1964  \
# 0             NaN           NaN           NaN           NaN           NaN
# ...

# %% [markdown]
# IMPUTING DATA

# %%
from sklearn.impute import SimpleImputer
import pandas as pd

# %%
gdp_data.isnull().sum()
# Out:
# Country Name        0
# Country Code        0
# Indicator Name      0
# Indicator Code      0
# 1960              140
#                  ...
# 2014               17
# 2015               18
# 2016               23
# 2017               30
# Unnamed: 62       264
# Length: 63, dtype: int64

# %%
# Convert non-numeric values to NaN
gdp_data = gdp_data.apply(pd.to_numeric, errors='coerce')

# %%
# Initialize the SimpleImputer with mean strategy
imputer = SimpleImputer(strategy='mean')

# %%
# Fit the SimpleImputer to compute imputation values
imputer.fit(gdp_data)
# Out:
# SimpleImputer()

# %%
# Transform the dataset to replace missing values
imputed_data = imputer.transform(gdp_data)
imputed_data
# Out:
# C:\Users\hello\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\impute\_base.py:577: UserWarning:
#
# Skipping features without any observed values: ['Country Name' 'Country Code' 'Indicator Name' 'Indicator Code'
#  'Unnamed: 62']. At least one non-missing value is needed for imputation with strategy='mean'.
# array([[7.08125130e+10, 7.35340700e+10, 7.80094843e+10, ...,
#         2.50567112e+12, 2.58624127e+12, 2.84792756e+12],
#        [5.37777811e+08, 5.48888896e+08, 5.46666678e+08, ...,
#         1.92155622e+10, 1.94690222e+10, 2.08153002e+10],
#        [7.08125130e+10, 7.35340700e+10, 7.80094843e+10, ...,
#         1.02621216e+11, 9.53372035e+10, 1.24209386e+11],
#        ...,
#        [7.57524850e+09, 7.97284054e+09, 8.49783004e+09, ...,
#         3.17741039e+11, 2.95762685e+11, 3.49419344e+11],
#        [7.13000000e+08, 6.96285714e+08, 6.93142857e+08, ...,
#         2.11543945e+10, 2.09547544e+10, 2.58086664e+10],
# ...

# %% [markdown]
# MISSING VALUE

# %%
gdp_data_check_missing = gdp_data.isnull().sum()

print("Mengecek data yang hilang\n")
gdp_data_check_missing
# Out:
# Mengecek data yang hilang
# Country Name      264
# Country Code      264
# Indicator Name    264
# Indicator Code    264
# 1960              140
#                  ...
# 2014               17
# 2015               18
# 2016               23
# 2017               30
# Unnamed: 62       264
# Length: 63, dtype: int64

# %%
import pandas as pd
from sklearn.impute import SimpleImputer

# %% [markdown]
# CLEANING DATA

# %%
gdp_data_cleaned = gdp_data.dropna(axis=1, how='all')

print("Setelah mengecek data yang hilang")
gdp_data_cleaned
# Out:
# Setelah mengecek data yang hilang
#              1960          1961          1962          1963          1964  \
# 0             NaN           NaN           NaN           NaN           NaN
# 1    5.377778e+08  5.488889e+08  5.466667e+08  7.511112e+08  8.000000e+08
# 2             NaN           NaN           NaN           NaN           NaN
# 3             NaN           NaN           NaN           NaN           NaN
# 4             NaN           NaN           NaN           NaN           NaN
# ..            ...           ...           ...           ...           ...
# 259           NaN           NaN           NaN           NaN           NaN
# 260           NaN           NaN           NaN           NaN           NaN
# 261  7.575248e+09  7.972841e+09  8.497830e+09  9.423212e+09  1.037379e+10
# 262  7.130000e+08  6.962857e+08  6.931429e+08  7.187143e+08  8.394286e+08
# 263  1.052990e+09  1.096647e+09  1.117602e+09  1.159512e+09  1.217138e+09
#
# ...

# %% [markdown]
# DATA DUPLICATE

# %%
gdp_data_duplicate = gdp_data_cleaned.drop_duplicates()

gdp_data_duplicate.to_csv("data_clean/gdp_data_clean.csv", index=False)
gdp_data_duplicate
# Out:
#              1960          1961          1962          1963          1964  \
# 0             NaN           NaN           NaN           NaN           NaN
# 1    5.377778e+08  5.488889e+08  5.466667e+08  7.511112e+08  8.000000e+08
# 2             NaN           NaN           NaN           NaN           NaN
# 3             NaN           NaN           NaN           NaN           NaN
# 4             NaN           NaN           NaN           NaN           NaN
# ..            ...           ...           ...           ...           ...
# 259           NaN           NaN           NaN           NaN           NaN
# 260           NaN           NaN           NaN           NaN           NaN
# 261  7.575248e+09  7.972841e+09  8.497830e+09  9.423212e+09  1.037379e+10
# 262  7.130000e+08  6.962857e+08  6.931429e+08  7.187143e+08  8.394286e+08
# 263  1.052990e+09  1.096647e+09  1.117602e+09  1.159512e+09  1.217138e+09
#
#              1965          1966          1967          1968          1969  \
# ...

# %% [markdown]
# # MYSTERY

# %% [markdown]
# EXTRACT

# %%
import pandas as pd

# %%
# Read the CSV file into a DataFrame with 'utf-16' encoding
mystery = pd.read_csv("E:\\DE-Mini-Project\\data_source\\mystery.csv", encoding='utf-16')

# %%
mystery
# Out:
#      Unnamed: 0  Country Name Country Code     Indicator Name Indicator Code  \
# 0             0         Aruba          ABW  Population, total    SP.POP.TOTL
# 1             1   Afghanistan          AFG  Population, total    SP.POP.TOTL
# 2             2        Angola          AGO  Population, total    SP.POP.TOTL
# 3             3       Albania          ALB  Population, total    SP.POP.TOTL
# 4             4       Andorra          AND  Population, total    SP.POP.TOTL
# ..          ...           ...          ...                ...            ...
# 259         259        Kosovo          XKX  Population, total    SP.POP.TOTL
# 260         260   Yemen, Rep.          YEM  Population, total    SP.POP.TOTL
# 261         261  South Africa          ZAF  Population, total    SP.POP.TOTL
# 262         262        Zambia          ZMB  Population, total    SP.POP.TOTL
# 263         263      Zimbabwe          ZWE  Population, total    SP.POP.TOTL
#
# ...

# %% [markdown]
# MISSING VALUE

# %%
mystery_check_missing = mystery.isnull().sum()

print("Mengecek data yang hilang\n")
print(mystery_check_missing)
# Out:
# Mengecek data yang hilang
#
# Unnamed: 0        0
# Country Name      0
# Country Code      0
# Indicator Name    0
# Indicator Code    0
#                  ..
# 2013              2
# 2014              2
# 2015              2
# 2016              2
# 2017              2
# Length: 63, dtype: int64

# %% [markdown]
# DATA DUPLICATE

# %%
# Check duplicate data
duplicate_rows = mystery.duplicated().sum()
print("Hasil Duplikat Data:\n", duplicate_rows)

mystery
# Out:
# Hasil Duplikat Data:
#  0
#      Unnamed: 0  Country Name Country Code     Indicator Name Indicator Code  \
# 0             0         Aruba          ABW  Population, total    SP.POP.TOTL
# 1             1   Afghanistan          AFG  Population, total    SP.POP.TOTL
# 2             2        Angola          AGO  Population, total    SP.POP.TOTL
# 3             3       Albania          ALB  Population, total    SP.POP.TOTL
# 4             4       Andorra          AND  Population, total    SP.POP.TOTL
# ..          ...           ...          ...                ...            ...
# 259         259        Kosovo          XKX  Population, total    SP.POP.TOTL
# 260         260   Yemen, Rep.          YEM  Population, total    SP.POP.TOTL
# 261         261  South Africa          ZAF  Population, total    SP.POP.TOTL
# 262         262        Zambia          ZMB  Population, total    SP.POP.TOTL
# 263         263      Zimbabwe          ZWE  Population, total    SP.POP.TOTL
#
# ...

# %% [markdown]
# CLEANING DATA

# %%
mystery_cleaned = mystery.dropna(axis=1, how='all')

print("Setelah mengecek data yang hilang")
mystery_cleaned
# Out:
# Setelah mengecek data yang hilang
#      Unnamed: 0  Country Name Country Code     Indicator Name Indicator Code  \
# 0             0         Aruba          ABW  Population, total    SP.POP.TOTL
# 1             1   Afghanistan          AFG  Population, total    SP.POP.TOTL
# 2             2        Angola          AGO  Population, total    SP.POP.TOTL
# 3             3       Albania          ALB  Population, total    SP.POP.TOTL
# 4             4       Andorra          AND  Population, total    SP.POP.TOTL
# ..          ...           ...          ...                ...            ...
# 259         259        Kosovo          XKX  Population, total    SP.POP.TOTL
# 260         260   Yemen, Rep.          YEM  Population, total    SP.POP.TOTL
# 261         261  South Africa          ZAF  Population, total    SP.POP.TOTL
# 262         262        Zambia          ZMB  Population, total    SP.POP.TOTL
# 263         263      Zimbabwe          ZWE  Population, total    SP.POP.TOTL
#
# ...

# %% [markdown]
# ENCODING DATASET

# %%
mystery_url = 'E:\DE-Mini-Project\data_source\mystery.csv'

df_mystery = pd.read_csv(mystery_url, encoding='utf-16')
df_mystery.head()
# Out:
#    Unnamed: 0 Country Name Country Code     Indicator Name Indicator Code  \
# 0           0        Aruba          ABW  Population, total    SP.POP.TOTL
# 1           1  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 2           2       Angola          AGO  Population, total    SP.POP.TOTL
# 3           3      Albania          ALB  Population, total    SP.POP.TOTL
# 4           4      Andorra          AND  Population, total    SP.POP.TOTL
#
#         1960       1961       1962       1963       1964  ...        2008  \
# 0    54211.0    55438.0    56225.0    56695.0    57032.0  ...    101353.0
# 1  8996351.0  9166764.0  9345868.0  9533954.0  9731361.0  ...  27294031.0
# 2  5643182.0  5753024.0  5866061.0  5980417.0  6093321.0  ...  21759420.0
# 3  1608800.0  1659800.0  1711319.0  1762621.0  1814135.0  ...   2947314.0
# 4    13411.0    14375.0    15370.0    16412.0    17469.0  ...     83861.0
#
# ...

# %% [markdown]
# # POPULATION CSV

# %%
import pandas as pd

# %% [markdown]
# EXTRACT

# %%
population_csv = pd.read_csv ("E:\DE-Mini-Project\data_source\population_data.csv")
population_csv
# Out:
#      Country Name Country Code     Indicator Name Indicator Code        1960  \
# 0           Aruba          ABW  Population, total    SP.POP.TOTL     54211.0
# 1     Afghanistan          AFG  Population, total    SP.POP.TOTL   8996351.0
# 2          Angola          AGO  Population, total    SP.POP.TOTL   5643182.0
# 3         Albania          ALB  Population, total    SP.POP.TOTL   1608800.0
# 4         Andorra          AND  Population, total    SP.POP.TOTL     13411.0
# ..            ...          ...                ...            ...         ...
# 259        Kosovo          XKX  Population, total    SP.POP.TOTL    947000.0
# 260   Yemen, Rep.          YEM  Population, total    SP.POP.TOTL   5172135.0
# 261  South Africa          ZAF  Population, total    SP.POP.TOTL  17456855.0
# 262        Zambia          ZMB  Population, total    SP.POP.TOTL   3044846.0
# 263      Zimbabwe          ZWE  Population, total    SP.POP.TOTL   3747369.0
#
# ...

# %% [markdown]
# MISSING VALUE

# %%
population_csv_check_missing = population_csv.isnull().sum()

print("Mengecek data yang hilang\n")
print(population_csv_check_missing)
# Out:
# Mengecek data yang hilang
#
# Country Name        0
# Country Code        0
# Indicator Name      0
# Indicator Code      0
# 1960                4
#                  ...
# 2014                2
# 2015                2
# 2016                2
# 2017                2
# Unnamed: 62       264
# Length: 63, dtype: int64

# %%
population_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264 entries, 0 to 263
# Data columns (total 63 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    264 non-null    object
#  1   Country Code    264 non-null    object
#  2   Indicator Name  264 non-null    object
#  3   Indicator Code  264 non-null    object
#  4   1960            260 non-null    float64
#  5   1961            260 non-null    float64
#  6   1962            260 non-null    float64
#  7   1963            260 non-null    float64
#  8   1964            260 non-null    float64
#  9   1965            260 non-null    float64
#  10  1966            260 non-null    float64
#  11  1967            260 non-null    float64
#  12  1968            260 non-null    float64
#  13  1969            260 non-null    float64
#  14  1970            260 non-null    float64
#  15  1971            260 non-null    float64
#  16  1972            260 non-null    float64
# ...

# %% [markdown]
# DATA DUPLICATE

# %%
# Check duplicate data
duplicate_rows = population_csv.duplicated().sum()
print("Hasil Duplikat Data:\n", duplicate_rows)

population_csv
# Out:
# Hasil Duplikat Data:
#  0
#      Country Name Country Code     Indicator Name Indicator Code        1960  \
# 0           Aruba          ABW  Population, total    SP.POP.TOTL     54211.0
# 1     Afghanistan          AFG  Population, total    SP.POP.TOTL   8996351.0
# 2          Angola          AGO  Population, total    SP.POP.TOTL   5643182.0
# 3         Albania          ALB  Population, total    SP.POP.TOTL   1608800.0
# 4         Andorra          AND  Population, total    SP.POP.TOTL     13411.0
# ..            ...          ...                ...            ...         ...
# 259        Kosovo          XKX  Population, total    SP.POP.TOTL    947000.0
# 260   Yemen, Rep.          YEM  Population, total    SP.POP.TOTL   5172135.0
# 261  South Africa          ZAF  Population, total    SP.POP.TOTL  17456855.0
# 262        Zambia          ZMB  Population, total    SP.POP.TOTL   3044846.0
# 263      Zimbabwe          ZWE  Population, total    SP.POP.TOTL   3747369.0
#
# ...

# %% [markdown]
# CLEANING DATA

# %%
population_csv_cleaned = population_csv.dropna(axis=1, how='all')

print("Setelah data yang hilang")
population_csv_cleaned
# Out:
# Setelah data yang hilang
#      Country Name Country Code     Indicator Name Indicator Code        1960  \
# 0           Aruba          ABW  Population, total    SP.POP.TOTL     54211.0
# 1     Afghanistan          AFG  Population, total    SP.POP.TOTL   8996351.0
# 2          Angola          AGO  Population, total    SP.POP.TOTL   5643182.0
# 3         Albania          ALB  Population, total    SP.POP.TOTL   1608800.0
# 4         Andorra          AND  Population, total    SP.POP.TOTL     13411.0
# ..            ...          ...                ...            ...         ...
# 259        Kosovo          XKX  Population, total    SP.POP.TOTL    947000.0
# 260   Yemen, Rep.          YEM  Population, total    SP.POP.TOTL   5172135.0
# 261  South Africa          ZAF  Population, total    SP.POP.TOTL  17456855.0
# 262        Zambia          ZMB  Population, total    SP.POP.TOTL   3044846.0
# 263      Zimbabwe          ZWE  Population, total    SP.POP.TOTL   3747369.0
#
# ...

# %%
population_csv.dtypes
# Out:
# Country Name       object
# Country Code       object
# Indicator Name     object
# Indicator Code     object
# 1960              float64
#                    ...
# 2014              float64
# 2015              float64
# 2016              float64
# 2017              float64
# Unnamed: 62       float64
# Length: 63, dtype: object

# %% [markdown]
# PENYESUAIAN TIPE DATA

# %%
# Calculate the population sum by year for Canada,
#       the United States, and Mexico.

# the keepcol variable makes a list of the column names to keep. You can use this if you'd like
keepcol = ['Country Name']
for i in range(1960, 2018, 1):
    keepcol.append(str(i))

# In the df_nafta variable, store a data frame that only contains the rows for 
#      Canada, United States, and Mexico.
df_nafta = population_csv[(population_csv['Country Name'] == 'Canada') | 
             (population_csv['Country Name'] == 'United States') | 
            (population_csv['Country Name'] == 'Mexico')].iloc[:,]


# Calculate the sum of the values in each column in order to find the total population by year.
# You can use the keepcol variable if you want to control which columns get outputted
df_nafta.sum(axis=0)[keepcol]

df_nafta
# Out:
#       Country Name Country Code     Indicator Name Indicator Code  \
# 33          Canada          CAN  Population, total    SP.POP.TOTL
# 152         Mexico          MEX  Population, total    SP.POP.TOTL
# 249  United States          USA  Population, total    SP.POP.TOTL
#
#             1960         1961         1962         1963         1964  \
# 33    17909009.0   18271000.0   18614000.0   18964000.0   19325000.0
# 152   38174112.0   39394126.0   40649588.0   41939880.0   43264272.0
# 249  180671000.0  183691000.0  186538000.0  189242000.0  191889000.0
#
#             1965  ...         2009         2010         2011         2012  \
# 33    19678000.0  ...   33628571.0   34005274.0   34342780.0   34750545.0
# 152   44623043.0  ...  115505228.0  117318941.0  119090017.0  120828307.0
# 249  194303000.0  ...  306771529.0  309338421.0  311644280.0  313993272.0
#
#             2013         2014         2015         2016         2017  \
# ...

# %%
population_csv.dtypes
# Out:
# Country Name       object
# Country Code       object
# Indicator Name     object
# Indicator Code     object
# 1960              float64
#                    ...
# 2014              float64
# 2015              float64
# 2016              float64
# 2017              float64
# Unnamed: 62       float64
# Length: 63, dtype: object

# %% [markdown]
# # PROJECTS DATA

# %% [markdown]
# EXTRACT

# %%
import pandas as pd

# %%
df_project = pd.read_csv("E:\DE-Mini-Project\data_source\projects_data.csv")
df_project
# Out:
# C:\Users\hello\AppData\Local\Temp\ipykernel_23664\1307407248.py:1: DtypeWarning:
#
# Columns (44) have mixed types. Specify dtype option on import or set low_memory=False.
#             id                   regionname  \
# 0      P162228                        Other
# 1      P163962                       Africa
# 2      P167672                   South Asia
# 3      P158768                   South Asia
# 4      P161364                       Africa
# ...        ...                          ...
# 18243  P006578  Latin America and Caribbean
# 18244  P037451      Europe and Central Asia
# 18245  P037362      Europe and Central Asia
# 18246  P037452      Europe and Central Asia
# 18247  P037383      Europe and Central Asia
#
#                                              countryname prodline  \
# 0                                            World;World       RE
# 1      Democratic Republic of the Congo;Democratic Re...       PE
# ...

# %% [markdown]
# MISSING VALUES

# %%
#Cek missing values
missing_values = df_project.isnull().sum()
print("Hasil missing values:\n", missing_values)
# Out:
# Hasil missing values:
#  id                              0
# regionname                      0
# countryname                     0
# prodline                        0
# lendinginstr                  246
# lendinginstrtype              246
# envassesmentcategorycode     5811
# supplementprojectflg           53
# productlinetype                 0
# projectstatusdisplay            4
# status                          4
# project_name                    0
# boardapprovaldate            1504
# board_approval_month         1504
# closingdate                  3349
# lendprojectcost               125
# ibrdcommamt                     0
# idacommamt                      0
# totalamt                        0
# grantamt                        0
# borrower                     5919
# impagency                    6097
# url                             0
# projectdoc                  18248
# majorsector_percent         18248
# sector1                         0
# sector2                      8721
# ...

# %% [markdown]
# DUPLICATE DATA

# %%
# Check duplicate data
duplicate_rows = df_project.duplicated().sum()
print("Hasil Duplikat Data:\n", duplicate_rows)

df_project
# Out:
# Hasil Duplikat Data:
#  0
#             id                   regionname  \
# 0      P162228                        Other
# 1      P163962                       Africa
# 2      P167672                   South Asia
# 3      P158768                   South Asia
# 4      P161364                       Africa
# ...        ...                          ...
# 18243  P006578  Latin America and Caribbean
# 18244  P037451      Europe and Central Asia
# 18245  P037362      Europe and Central Asia
# 18246  P037452      Europe and Central Asia
# 18247  P037383      Europe and Central Asia
#
#                                              countryname prodline  \
# 0                                            World;World       RE
# 1      Democratic Republic of the Congo;Democratic Re...       PE
# 2      People's Republic of Bangladesh;People's Repub...       PE
# 3      Islamic  Republic of Afghanistan;Islamic  Repu...       PE
# 4      Federal Republic of Nigeria;Federal Republic o...       PE
# ...

# %% [markdown]
# CLEANING DATA

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler

# %%
import pandas as pd

# %%
# Read the CSV file into a DataFrame
df_project = pd.read_csv("E:\DE-Mini-Project\data_source\projects_data.csv")
# Out:
# C:\Users\hello\AppData\Local\Temp\ipykernel_23664\4091332091.py:2: DtypeWarning:
#
# Columns (44) have mixed types. Specify dtype option on import or set low_memory=False.

# %%
# Display the column names in the DataFrame
print(df_project.columns)
# Out:
# Index(['id', 'regionname', 'countryname', 'prodline', 'lendinginstr',
#        'lendinginstrtype', 'envassesmentcategorycode', 'supplementprojectflg',
#        'productlinetype', 'projectstatusdisplay', 'status', 'project_name',
#        'boardapprovaldate', 'board_approval_month', 'closingdate',
#        'lendprojectcost', 'ibrdcommamt', 'idacommamt', 'totalamt', 'grantamt',
#        'borrower', 'impagency', 'url', 'projectdoc ', 'majorsector_percent ',
#        'sector1', 'sector2', 'sector3', 'sector4', 'sector5', 'sector',
#        'mjsector1', 'mjsector2', 'mjsector3', 'mjsector4', 'mjsector5',
#        'mjsector', 'theme1', 'theme2', 'theme3', 'theme4', 'theme5', 'theme ',
#        'goal', 'financier', 'mjtheme1name', 'mjtheme2name', 'mjtheme3name',
#        'mjtheme4name', 'mjtheme5name', 'location', 'GeoLocID', 'GeoLocName',
#        'Latitude', 'Longitude', 'Country', 'Unnamed: 56'],
#       dtype='object')

# %%
columns_to_drop = ['mjtheme1name', 'mjtheme2name', 'mjtheme3name', 'mjtheme4name', 'mjtheme5name', 'mjsector1', 'mjsector2', 'mjsector3', 'mjsector4', 'mjsector5', 'location', 'GeoLocID', 'GeoLocName', 'Latitude', 'Longitude', 'Unnamed: 56', 'url', 'envassesmentcategorycode', 'borrower', 'impagency', 'sector2', 'sector3', 'sector4', 'sector5', 'theme2', 'theme3', 'theme4', 'theme5', 'goal', 'financier', 'Country']
df_project.drop(columns=columns_to_drop, inplace=True)

df_project
# Out:
#             id                   regionname  \
# 0      P162228                        Other
# 1      P163962                       Africa
# 2      P167672                   South Asia
# 3      P158768                   South Asia
# 4      P161364                       Africa
# ...        ...                          ...
# 18243  P006578  Latin America and Caribbean
# 18244  P037451      Europe and Central Asia
# 18245  P037362      Europe and Central Asia
# 18246  P037452      Europe and Central Asia
# 18247  P037383      Europe and Central Asia
#
#                                              countryname prodline  \
# 0                                            World;World       RE
# 1      Democratic Republic of the Congo;Democratic Re...       PE
# 2      People's Republic of Bangladesh;People's Repub...       PE
# 3      Islamic  Republic of Afghanistan;Islamic  Repu...       PE
# 4      Federal Republic of Nigeria;Federal Republic o...       PE
# ...

# %%
columns_to_drop = ['projectdoc ', 'majorsector_percent ', 'theme ']
df_project.drop(columns=columns_to_drop, inplace=True)

df_project
# Out:
#             id                   regionname  \
# 0      P162228                        Other
# 1      P163962                       Africa
# 2      P167672                   South Asia
# 3      P158768                   South Asia
# 4      P161364                       Africa
# ...        ...                          ...
# 18243  P006578  Latin America and Caribbean
# 18244  P037451      Europe and Central Asia
# 18245  P037362      Europe and Central Asia
# 18246  P037452      Europe and Central Asia
# 18247  P037383      Europe and Central Asia
#
#                                              countryname prodline  \
# 0                                            World;World       RE
# 1      Democratic Republic of the Congo;Democratic Re...       PE
# 2      People's Republic of Bangladesh;People's Repub...       PE
# 3      Islamic  Republic of Afghanistan;Islamic  Repu...       PE
# 4      Federal Republic of Nigeria;Federal Republic o...       PE
# ...

# %%
df_project.columns
df_project.dtypes
# Out:
# id                      object
# regionname              object
# countryname             object
# prodline                object
# lendinginstr            object
# lendinginstrtype        object
# supplementprojectflg    object
# productlinetype         object
# projectstatusdisplay    object
# status                  object
# project_name            object
# boardapprovaldate       object
# board_approval_month    object
# closingdate             object
# lendprojectcost         object
# ibrdcommamt             object
# idacommamt              object
# totalamt                object
# grantamt                object
# sector1                 object
# sector                  object
# mjsector                object
# theme1                  object
# dtype: object

# %% [markdown]
# PENYESUAIAN TIPE DATA

# %%
# Konversi kolom 'boardapprovaldate' menjadi datetime
df_project['boardapprovaldate'] = pd.to_datetime(df_project['boardapprovaldate'])

# Konversi kolom 'closingdate' menjadi datetime
df_project['closingdate'] = pd.to_datetime(df_project['closingdate'])
df_project['closingdate'] = df_project['closingdate'].dt.strftime('%d-%m-%Y')

# Menghilangkan koma
columns = ['lendprojectcost', 'ibrdcommamt', 'idacommamt', 'totalamt', 'grantamt']
df_project = df_project.replace({',': ''}, regex=True)

# Konversi data numeric
df_project[columns] = df_project[columns].apply(pd.to_numeric, errors='coerce')

df_project.to_csv("penyesuaian_tipe_data/project_data_penyesuaian.csv", index=False)
df_project
# Out:
#             id                   regionname  \
# 0      P162228                        Other
# 1      P163962                       Africa
# 2      P167672                   South Asia
# 3      P158768                   South Asia
# 4      P161364                       Africa
# ...        ...                          ...
# 18243  P006578  Latin America and Caribbean
# 18244  P037451      Europe and Central Asia
# 18245  P037362      Europe and Central Asia
# 18246  P037452      Europe and Central Asia
# 18247  P037383      Europe and Central Asia
#
#                                              countryname prodline  \
# 0                                            World;World       RE
# 1      Democratic Republic of the Congo;Democratic Re...       PE
# 2      People's Republic of Bangladesh;People's Repub...       PE
# 3      Islamic  Republic of Afghanistan;Islamic  Repu...       PE
# 4      Federal Republic of Nigeria;Federal Republic o...       PE
# ...

# %% [markdown]
# DUMMY VARIABLES

# %%
categorical_cols = ['status']

df_project = pd.get_dummies(df_project, columns=categorical_cols)

df_project
# Out:
#             id                   regionname  \
# 0      P162228                        Other
# 1      P163962                       Africa
# 2      P167672                   South Asia
# 3      P158768                   South Asia
# 4      P161364                       Africa
# ...        ...                          ...
# 18243  P006578  Latin America and Caribbean
# 18244  P037451      Europe and Central Asia
# 18245  P037362      Europe and Central Asia
# 18246  P037452      Europe and Central Asia
# 18247  P037383      Europe and Central Asia
#
#                                              countryname prodline  \
# 0                                            World;World       RE
# 1      Democratic Republic of the Congo;Democratic Re...       PE
# 2      People's Republic of Bangladesh;People's Repub...       PE
# 3      Islamic  Republic of Afghanistan;Islamic  Repu...       PE
# 4      Federal Republic of Nigeria;Federal Republic o...       PE
# ...

# %%
import pandas as pd

# %%
projects_data = pd.read_csv('E:\DE-Mini-Project\data_source\projects_data.csv')
# Out:
# C:\Users\hello\AppData\Local\Temp\ipykernel_23664\3437769994.py:1: DtypeWarning:
#
# Columns (44) have mixed types. Specify dtype option on import or set low_memory=False.

# %%
print(projects_data.columns)
# Out:
# Index(['id', 'regionname', 'countryname', 'prodline', 'lendinginstr',
#        'lendinginstrtype', 'envassesmentcategorycode', 'supplementprojectflg',
#        'productlinetype', 'projectstatusdisplay', 'status', 'project_name',
#        'boardapprovaldate', 'board_approval_month', 'closingdate',
#        'lendprojectcost', 'ibrdcommamt', 'idacommamt', 'totalamt', 'grantamt',
#        'borrower', 'impagency', 'url', 'projectdoc ', 'majorsector_percent ',
#        'sector1', 'sector2', 'sector3', 'sector4', 'sector5', 'sector',
#        'mjsector1', 'mjsector2', 'mjsector3', 'mjsector4', 'mjsector5',
#        'mjsector', 'theme1', 'theme2', 'theme3', 'theme4', 'theme5', 'theme ',
#        'goal', 'financier', 'mjtheme1name', 'mjtheme2name', 'mjtheme3name',
#        'mjtheme4name', 'mjtheme5name', 'location', 'GeoLocID', 'GeoLocName',
#        'Latitude', 'Longitude', 'Country', 'Unnamed: 56'],
#       dtype='object')

# %% [markdown]
# REPLACE DAN REGEX

# %%
import sqlite3

# %%
columns_to_replace = ['sector', 'countryname']

for col in columns_to_replace:
    df_project[col] = df_project[col].apply(lambda x: ','.join(set(x.split(';'))) if isinstance(x, str) else x)

df_project['sector'] = df_project['sector'].str.replace(';', '; ')
df_project['countryname'] = df_project['countryname'].str.replace(';', ' ')

df_project[['theme1', 'sector1']] = df_project[['theme1', 'sector1']].replace(regex=True, to_replace=r'!.*', value='')

df_project
# Out:
#             id                   regionname                       countryname  \
# 0      P162228                        Other                             World
# 1      P163962                       Africa  Democratic Republic of the Congo
# 2      P167672                   South Asia   People's Republic of Bangladesh
# 3      P158768                   South Asia  Islamic  Republic of Afghanistan
# 4      P161364                       Africa       Federal Republic of Nigeria
# ...        ...                          ...                               ...
# 18243  P006578  Latin America and Caribbean                 Republic of Chile
# 18244  P037451      Europe and Central Asia         Grand Duchy of Luxembourg
# 18245  P037362      Europe and Central Asia                Kingdom of Denmark
# 18246  P037452      Europe and Central Asia        Kingdom of the Netherlands
# 18247  P037383      Europe and Central Asia                   French Republic
#
# ...

# %% [markdown]
# #  RURAL_POPULATION_PERCENT

# %% [markdown]
# EXTRACT

# %%
rural = pd.read_csv("data_source/rural_population_percent.csv")
print ("Rural Population Percent")
rural
# Out:
# Rural Population Percent
#      Country Name Country Code                            Indicator Name  \
# 0           Aruba          ABW  Rural population (% of total population)
# 1     Afghanistan          AFG  Rural population (% of total population)
# 2          Angola          AGO  Rural population (% of total population)
# 3         Albania          ALB  Rural population (% of total population)
# 4         Andorra          AND  Rural population (% of total population)
# ..            ...          ...                                       ...
# 259        Kosovo          XKX  Rural population (% of total population)
# 260   Yemen, Rep.          YEM  Rural population (% of total population)
# 261  South Africa          ZAF  Rural population (% of total population)
# 262        Zambia          ZMB  Rural population (% of total population)
# 263      Zimbabwe          ZWE  Rural population (% of total population)
#
# ...

# %% [markdown]
# MISSING VALUES

# %%
rural_check_missing = rural.isnull().sum()

print("Mengecek data yang hilang\n")
print(rural_check_missing)
# Out:
# Mengecek data yang hilang
#
# Country Name        0
# Country Code        0
# Indicator Name      0
# Indicator Code      0
# 1960                5
#                  ...
# 2014                4
# 2015                4
# 2016                4
# 2017                4
# Unnamed: 62       264
# Length: 63, dtype: int64

# %% [markdown]
# CLEANING DATA

# %%
rural_cleaned = rural.dropna(axis=1, how='all')

print("Setelah mengecek data yang hilang")
print(rural_cleaned)
# Out:
# Setelah mengecek data yang hilang
#      Country Name Country Code                            Indicator Name  \
# 0           Aruba          ABW  Rural population (% of total population)
# 1     Afghanistan          AFG  Rural population (% of total population)
# 2          Angola          AGO  Rural population (% of total population)
# 3         Albania          ALB  Rural population (% of total population)
# 4         Andorra          AND  Rural population (% of total population)
# ..            ...          ...                                       ...
# 259        Kosovo          XKX  Rural population (% of total population)
# 260   Yemen, Rep.          YEM  Rural population (% of total population)
# 261  South Africa          ZAF  Rural population (% of total population)
# 262        Zambia          ZMB  Rural population (% of total population)
# 263      Zimbabwe          ZWE  Rural population (% of total population)
#
# ...

# %% [markdown]
# DATA DUPLICATE

# %%
rural_duplicate = rural_cleaned.drop_duplicates()

print(rural_duplicate)

rural_duplicate.to_csv("data_clean/rural_population_percent_clean.csv", index=False)
# Out:
#      Country Name Country Code                            Indicator Name  \
# 0           Aruba          ABW  Rural population (% of total population)
# 1     Afghanistan          AFG  Rural population (% of total population)
# 2          Angola          AGO  Rural population (% of total population)
# 3         Albania          ALB  Rural population (% of total population)
# 4         Andorra          AND  Rural population (% of total population)
# ..            ...          ...                                       ...
# 259        Kosovo          XKX  Rural population (% of total population)
# 260   Yemen, Rep.          YEM  Rural population (% of total population)
# 261  South Africa          ZAF  Rural population (% of total population)
# 262        Zambia          ZMB  Rural population (% of total population)
# 263      Zimbabwe          ZWE  Rural population (% of total population)
#
#      Indicator Code    1960    1961    1962    1963    1964    1965  ...  \
# ...

# %% [markdown]
# # POPULATION JSON

# %% [markdown]
# EXTRACT

# %%
population_json = pd.read_json("data_source/population_data.json")
print ("Population Data")
population_json
# Out:
# Population Data
#      Country Name Country Code     Indicator Name Indicator Code        1960  \
# 0           Aruba          ABW  Population, total    SP.POP.TOTL     54211.0
# 1     Afghanistan          AFG  Population, total    SP.POP.TOTL   8996351.0
# 2          Angola          AGO  Population, total    SP.POP.TOTL   5643182.0
# 3         Albania          ALB  Population, total    SP.POP.TOTL   1608800.0
# 4         Andorra          AND  Population, total    SP.POP.TOTL     13411.0
# ..            ...          ...                ...            ...         ...
# 259        Kosovo          XKX  Population, total    SP.POP.TOTL    947000.0
# 260   Yemen, Rep.          YEM  Population, total    SP.POP.TOTL   5172135.0
# 261  South Africa          ZAF  Population, total    SP.POP.TOTL  17456855.0
# 262        Zambia          ZMB  Population, total    SP.POP.TOTL   3044846.0
# 263      Zimbabwe          ZWE  Population, total    SP.POP.TOTL   3747369.0
#
# ...

# %% [markdown]
# MISSING VALUES

# %%
population_json_check_missing = population_json.isnull().sum()

print("Mengecek data yang hilang\n")
print(population_json_check_missing)
# Out:
# Mengecek data yang hilang
#
# Country Name      0
# Country Code      0
# Indicator Name    0
# Indicator Code    0
# 1960              4
#                  ..
# 2013              2
# 2014              2
# 2015              2
# 2016              2
# 2017              2
# Length: 62, dtype: int64

# %% [markdown]
# PENYESUAIAN TIPE DATA

# %%
import pandas as pd

# Baca dataset JSON ke dalam DataFrame
population_json = pd.read_json('E:\DE-Mini-Project\data_source\population_data.json')

# %%
# Periksa tipe data saat ini
print(population_json.dtypes)
# Out:
# Country Name       object
# Country Code       object
# Indicator Name     object
# Indicator Code     object
# 1960              float64
#                    ...
# 2013              float64
# 2014              float64
# 2015              float64
# 2016              float64
# 2017              float64
# Length: 62, dtype: object

# %%
# Contoh konversi tipe data
#df['nama_kolom'] = df['nama_kolom'].astype('tipe_data_baru')
#df['nama_kolom_numerik'] = pd.to_numeric(df['nama_kolom_numerik'], errors='coerce')
#df['kolom_tanggal'] = pd.to_datetime(df['kolom_tanggal'])

# %%
# Calculate the population sum by year for Canada,
#       the United States, and Mexico.

# the keepcol variable makes a list of the column names to keep. You can use this if you'd like
keepcol = ['Country Name']
for i in range(1960, 2018, 1):
    keepcol.append(str(i))

# In the df_nafta variable, store a data frame that only contains the rows for 
#      Canada, United States, and Mexico.
df_nafta = population_json[(population_json['Country Name'] == 'Albania	')].iloc[:,]


# Calculate the sum of the values in each column in order to find the total population by year.
# You can use the keepcol variable if you want to control which columns get outputted
df_nafta.sum(axis=0)[keepcol]

df_nafta
# Out:
# Empty DataFrame
# Columns: [Country Name, Country Code, Indicator Name, Indicator Code, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017]
# Index: []
#
# [0 rows x 62 columns]

# %%
import pandas as pd

# %%
# Membaca dataset
population_json = pd.read_json("E:\DE-Mini-Project\data_source\population_data.json")

# %%
# Menyesuaikan tipe data kolom tertentu
population_json ['Indicator Code'] = pd.to_numeric(population_json['Indicator Code'], errors='coerce')  # Menyesuaikan kolom Country Name menjadi tipe data numerik (float atau integer)
population_json ['Country Name'] = pd.to_numeric(population_json['Country Name'], errors='coerce')  # Menyesuaikan kolom Country Name menjadi tipe data numerik (float atau integer)
# Menampilkan informasi tipe data setelah penyesuaian
population_json
# Out:
#      Country Name Country Code     Indicator Name  Indicator Code        1960  \
# 0             NaN          ABW  Population, total             NaN     54211.0
# 1             NaN          AFG  Population, total             NaN   8996351.0
# 2             NaN          AGO  Population, total             NaN   5643182.0
# 3             NaN          ALB  Population, total             NaN   1608800.0
# 4             NaN          AND  Population, total             NaN     13411.0
# ..            ...          ...                ...             ...         ...
# 259           NaN          XKX  Population, total             NaN    947000.0
# 260           NaN          YEM  Population, total             NaN   5172135.0
# 261           NaN          ZAF  Population, total             NaN  17456855.0
# 262           NaN          ZMB  Population, total             NaN   3044846.0
# 263           NaN          ZWE  Population, total             NaN   3747369.0
#
# ...

# %%
population_json.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264 entries, 0 to 263
# Data columns (total 62 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    0 non-null      float64
#  1   Country Code    264 non-null    object
#  2   Indicator Name  264 non-null    object
#  3   Indicator Code  0 non-null      float64
#  4   1960            260 non-null    float64
#  5   1961            260 non-null    float64
#  6   1962            260 non-null    float64
#  7   1963            260 non-null    float64
#  8   1964            260 non-null    float64
#  9   1965            260 non-null    float64
#  10  1966            260 non-null    float64
#  11  1967            260 non-null    float64
#  12  1968            260 non-null    float64
#  13  1969            260 non-null    float64
#  14  1970            260 non-null    float64
#  15  1971            260 non-null    float64
#  16  1972            260 non-null    float64
# ...

# %%
print(population_json.head())
# Out:
#    Country Name Country Code     Indicator Name  Indicator Code       1960  \
# 0           NaN          ABW  Population, total             NaN    54211.0
# 1           NaN          AFG  Population, total             NaN  8996351.0
# 2           NaN          AGO  Population, total             NaN  5643182.0
# 3           NaN          ALB  Population, total             NaN  1608800.0
# 4           NaN          AND  Population, total             NaN    13411.0
#
#         1961       1962       1963       1964       1965  ...        2008  \
# 0    55438.0    56225.0    56695.0    57032.0    57360.0  ...    101353.0
# 1  9166764.0  9345868.0  9533954.0  9731361.0  9938414.0  ...  27294031.0
# 2  5753024.0  5866061.0  5980417.0  6093321.0  6203299.0  ...  21759420.0
# 3  1659800.0  1711319.0  1762621.0  1814135.0  1864791.0  ...   2947314.0
# 4    14375.0    15370.0    16412.0    17469.0    18549.0  ...     83861.0
#
# ...

# %%
print(population_json.columns)
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017'],
#       dtype='object')

# %% [markdown]
# CLEANING DATA

# %%
population_json_cleaned = population_json.dropna(axis=1, how='all')

print("Setelah mengecek data yang hilang")
print(population_json_cleaned)
# Out:
# Setelah mengecek data yang hilang
#     Country Code     Indicator Name        1960        1961        1962  \
# 0            ABW  Population, total     54211.0     55438.0     56225.0
# 1            AFG  Population, total   8996351.0   9166764.0   9345868.0
# 2            AGO  Population, total   5643182.0   5753024.0   5866061.0
# 3            ALB  Population, total   1608800.0   1659800.0   1711319.0
# 4            AND  Population, total     13411.0     14375.0     15370.0
# ..           ...                ...         ...         ...         ...
# 259          XKX  Population, total    947000.0    966000.0    994000.0
# 260          YEM  Population, total   5172135.0   5260501.0   5351799.0
# 261          ZAF  Population, total  17456855.0  17920673.0  18401608.0
# 262          ZMB  Population, total   3044846.0   3140264.0   3240587.0
# 263          ZWE  Population, total   3747369.0   3870756.0   3999419.0
#
# ...

# %% [markdown]
# DATA DUPLICATE

# %%
population_json_duplicate = population_json_cleaned.drop_duplicates()

print(population_json_duplicate)

population_json_duplicate.to_csv("data_clean/population_json_clean.csv", index=False)
# Out:
#     Country Code     Indicator Name        1960        1961        1962  \
# 0            ABW  Population, total     54211.0     55438.0     56225.0
# 1            AFG  Population, total   8996351.0   9166764.0   9345868.0
# 2            AGO  Population, total   5643182.0   5753024.0   5866061.0
# 3            ALB  Population, total   1608800.0   1659800.0   1711319.0
# 4            AND  Population, total     13411.0     14375.0     15370.0
# ..           ...                ...         ...         ...         ...
# 259          XKX  Population, total    947000.0    966000.0    994000.0
# 260          YEM  Population, total   5172135.0   5260501.0   5351799.0
# 261          ZAF  Population, total  17456855.0  17920673.0  18401608.0
# 262          ZMB  Population, total   3044846.0   3140264.0   3240587.0
# 263          ZWE  Population, total   3747369.0   3870756.0   3999419.0
#
#            1963        1964        1965        1966        1967  ...  \
# ...

# %% [markdown]
# # POPULATION DB

# %% [markdown]
# EXTRACT

# %%
# Connect to SQLite database
conn = sqlite3.connect("data_source/population_data.db")
cursor = conn.cursor()

# Perform select query
query = "SELECT * FROM population_data"
cursor.execute(query)

# Fetch all results
results = cursor.fetchall()

pdb = pd.DataFrame(results)

print(pdb.head())

# Close connection
conn.close()
# Out:
#    0            1    2                  3            4          5          6   \
# 0   0        Aruba  ABW  Population, total  SP.POP.TOTL    54211.0    55438.0
# 1   1  Afghanistan  AFG  Population, total  SP.POP.TOTL  8996351.0  9166764.0
# 2   2       Angola  AGO  Population, total  SP.POP.TOTL  5643182.0  5753024.0
# 3   3      Albania  ALB  Population, total  SP.POP.TOTL  1608800.0  1659800.0
# 4   4      Andorra  AND  Population, total  SP.POP.TOTL    13411.0    14375.0
#
#           7          8          9   ...          53          54          55  \
# 0    56225.0    56695.0    57032.0  ...    101353.0    101453.0    101669.0
# 1  9345868.0  9533954.0  9731361.0  ...  27294031.0  28004331.0  28803167.0
# 2  5866061.0  5980417.0  6093321.0  ...  21759420.0  22549547.0  23369131.0
# 3  1711319.0  1762621.0  1814135.0  ...   2947314.0   2927519.0   2913021.0
# 4    15370.0    16412.0    17469.0  ...     83861.0     84462.0     84449.0
#
# ...

# %%
import pandas as pd

# %%
import pandas as pd
import sqlite3

# %%
# Establish connection to the database
conn = sqlite3.connect('data_source/population_data.db')

# %%
# Execute the query and load data into a DataFrame
query = "SELECT * FROM population_data"  # Replace with your table name
population_data = pd.read_sql_query(query, conn)

# %%
# Verify the DataFrame by printing the first few rows
print(population_data.head())

# Close the connection
conn.close()
# Out:
#    index Country_Name Country_Code     Indicator_Name Indicator_Code  \
# 0      0        Aruba          ABW  Population, total    SP.POP.TOTL
# 1      1  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 2      2       Angola          AGO  Population, total    SP.POP.TOTL
# 3      3      Albania          ALB  Population, total    SP.POP.TOTL
# 4      4      Andorra          AND  Population, total    SP.POP.TOTL
#
#         1960       1961       1962       1963       1964  ...        2008  \
# 0    54211.0    55438.0    56225.0    56695.0    57032.0  ...    101353.0
# 1  8996351.0  9166764.0  9345868.0  9533954.0  9731361.0  ...  27294031.0
# 2  5643182.0  5753024.0  5866061.0  5980417.0  6093321.0  ...  21759420.0
# 3  1608800.0  1659800.0  1711319.0  1762621.0  1814135.0  ...   2947314.0
# 4    13411.0    14375.0    15370.0    16412.0    17469.0  ...     83861.0
#
#          2009        2010        2011        2012        2013        2014  \
# ...

# %% [markdown]
# PENYESUAIAN TIPE DATA

# %%
import sqlite3
import pandas as pd

# %%
# Menghubungkan ke database SQLite
conn = sqlite3.connect('E:\DE-Mini-Project\data_source\population_data.db')

# %%
# Membaca data dari tabel tertentu ke dalam DataFrame
population_data = pd.read_sql_query("SELECT * FROM population_data", conn)
population_data
# Out:
#      index  Country_Name Country_Code     Indicator_Name Indicator_Code  \
# 0        0         Aruba          ABW  Population, total    SP.POP.TOTL
# 1        1   Afghanistan          AFG  Population, total    SP.POP.TOTL
# 2        2        Angola          AGO  Population, total    SP.POP.TOTL
# 3        3       Albania          ALB  Population, total    SP.POP.TOTL
# 4        4       Andorra          AND  Population, total    SP.POP.TOTL
# ..     ...           ...          ...                ...            ...
# 259    259        Kosovo          XKX  Population, total    SP.POP.TOTL
# 260    260   Yemen, Rep.          YEM  Population, total    SP.POP.TOTL
# 261    261  South Africa          ZAF  Population, total    SP.POP.TOTL
# 262    262        Zambia          ZMB  Population, total    SP.POP.TOTL
# 263    263      Zimbabwe          ZWE  Population, total    SP.POP.TOTL
#
#            1960        1961        1962        1963        1964  ...  \
# ...

# %%
# Menyesuaikan tipe data kolom tertentu
#population_data['Country_Code'] = pd.to_numeric(population_data['Country_Code'])  
#population_data.dtypes

# %% [markdown]
# MISSING VALUE

# %%
population_data_check_missing = population_data.isnull().sum()

print("Mengecek data yang hilang\n")
print(population_data_check_missing)
# Out:
# Mengecek data yang hilang
#
# index             0
# Country_Name      0
# Country_Code      0
# Indicator_Name    0
# Indicator_Code    0
#                  ..
# 2013              2
# 2014              2
# 2015              2
# 2016              2
# 2017              2
# Length: 63, dtype: int64

# %% [markdown]
# CLEANING DATA

# %%
population_data_cleaned = population_data.dropna(axis=1, how='all')

print("Setelah mengecek data yang hilang")
print(population_data_cleaned)
# Out:
# Setelah mengecek data yang hilang
#      index  Country_Name Country_Code     Indicator_Name Indicator_Code  \
# 0        0         Aruba          ABW  Population, total    SP.POP.TOTL
# 1        1   Afghanistan          AFG  Population, total    SP.POP.TOTL
# 2        2        Angola          AGO  Population, total    SP.POP.TOTL
# 3        3       Albania          ALB  Population, total    SP.POP.TOTL
# 4        4       Andorra          AND  Population, total    SP.POP.TOTL
# ..     ...           ...          ...                ...            ...
# 259    259        Kosovo          XKX  Population, total    SP.POP.TOTL
# 260    260   Yemen, Rep.          YEM  Population, total    SP.POP.TOTL
# 261    261  South Africa          ZAF  Population, total    SP.POP.TOTL
# 262    262        Zambia          ZMB  Population, total    SP.POP.TOTL
# 263    263      Zimbabwe          ZWE  Population, total    SP.POP.TOTL
#
# ...

# %% [markdown]
# DUMMY VARIABLES

# %%
# import required modules
import pandas as pd
import numpy as np
 
# create dataset
population_data = pd.DataFrame({'Country_Name': ['Aruba', 'Afghanistan', 'Angola'],
                   })
 
# display dataset
print(population_data)
 
# create dummy variables
pd.get_dummies(population_data)
# Out:
#   Country_Name
# 0        Aruba
# 1  Afghanistan
# 2       Angola
#    Country_Name_Afghanistan  Country_Name_Angola  Country_Name_Aruba
# 0                     False                False                True
# 1                      True                False               False
# 2                     False                 True               False

# %% [markdown]
# DATA DUPLICATE

# %%
population_data_duplicate = population_data_cleaned.drop_duplicates()

print(population_data_duplicate)

population_data_duplicate.to_csv("data_clean/population_data_clean.db", index=False)
# Out:
#      index  Country_Name Country_Code     Indicator_Name Indicator_Code  \
# 0        0         Aruba          ABW  Population, total    SP.POP.TOTL
# 1        1   Afghanistan          AFG  Population, total    SP.POP.TOTL
# 2        2        Angola          AGO  Population, total    SP.POP.TOTL
# 3        3       Albania          ALB  Population, total    SP.POP.TOTL
# 4        4       Andorra          AND  Population, total    SP.POP.TOTL
# ..     ...           ...          ...                ...            ...
# 259    259        Kosovo          XKX  Population, total    SP.POP.TOTL
# 260    260   Yemen, Rep.          YEM  Population, total    SP.POP.TOTL
# 261    261  South Africa          ZAF  Population, total    SP.POP.TOTL
# 262    262        Zambia          ZMB  Population, total    SP.POP.TOTL
# 263    263      Zimbabwe          ZWE  Population, total    SP.POP.TOTL
#
#            1960        1961        1962        1963        1964  ...  \
# ...

# %% [markdown]
# # API

# %% [markdown]
# EXTRACT

# %%
# API endpoint
url = "http://api.worldbank.org/v2/countries/br;cn;us;id/indicators/SP.POP.TOTL/?format=json&per_page=1000"

# Send GET request
response = requests.get(url)
data = response.json()
total = data[0]['pages']

all_data = []

#Looping
for page in range(1, total + 1):
    page_url = f"{url}&page={page}"
    response =requests.get(page_url)
    data = response.json()
    all_data.extend(data[1])

API = pd.json_normalize(all_data)

API
# Out:
#     countryiso3code  date        value unit obs_status  decimal indicator.id  \
# 0               BRA  2023          NaN                        0  SP.POP.TOTL
# 1               BRA  2022  215313498.0                        0  SP.POP.TOTL
# 2               BRA  2021  214326223.0                        0  SP.POP.TOTL
# 3               BRA  2020  213196304.0                        0  SP.POP.TOTL
# 4               BRA  2019  211782878.0                        0  SP.POP.TOTL
# ..              ...   ...          ...  ...        ...      ...          ...
# 251             USA  1964  191889000.0                        0  SP.POP.TOTL
# 252             USA  1963  189242000.0                        0  SP.POP.TOTL
# 253             USA  1962  186538000.0                        0  SP.POP.TOTL
# 254             USA  1961  183691000.0                        0  SP.POP.TOTL
# 255             USA  1960  180671000.0                        0  SP.POP.TOTL
#
# ...

# %%
API.to_csv("penyesuaian_tipe_data/api_penyesuaian.csv", index=False)

# %% [markdown]
# PENYESUAIAN TIPE DATA

# %%
# Menghapus tanda "," 
API = API.replace({',': ''}, regex=True)

# Menghapus tanda "" 
API = API.applymap(lambda x: x.strip() if isinstance(x, str) else x)

# Menyimpan 
API.to_csv("penyesuaian_tipe_data/api_penyesuaian.csv", index=False)
# Out:
# C:\Users\hello\AppData\Local\Temp\ipykernel_23664\2255278783.py:5: FutureWarning:
#
# DataFrame.applymap has been deprecated. Use DataFrame.map instead.

# %% [markdown]
# # Extract XML

# %%
pip install lxml
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.4; however, version 24.0 is available.
# You should consider upgrading via the 'C:\Users\hello\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
pip install html5lib
# Out:
# ...
#
# ...
# WARNING: You are using pip version 21.2.4; however, version 24.0 is available.
# You should consider upgrading via the 'C:\Users\hello\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd
import xml.etree.ElementTree as ET

# %%
# Load and parse the XML file
tree = ET.parse('data_source/population_data.xml')
root = tree.getroot()

# %%
# Convert XML data into a list of dictionaries
data = []
for child in root:
    entry = {}
    for subchild in child:
        entry[subchild.tag] = subchild.text
    data.append(entry)

# %%
# Convert list of dictionaries to DataFrame
population_xml = pd.DataFrame(data)

# %%
# Verify the DataFrame
print(population_xml.head())
# Out:
#      record
# 0  \n

# %%
# Read the XML file
with open("data_source/population_data.xml", "r") as f:
    xml_data = f.read()

# %%
# Parse XML using Beautiful Soup
soup = BeautifulSoup(xml_data, "html.parser")
# Out:
# C:\Users\hello\AppData\Local\Programs\Python\Python310\lib\html\parser.py:170: XMLParsedAsHTMLWarning:
#
# It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.

# %%
# Extract data from XML and store in a list of dictionaries
data = []
for record in soup.find_all("record"):
    record_data = {}
    for field in record.find_all("field"):
        name = field.get("name")
        value = field.text
        record_data[name] = value
    data.append(record_data)

# %%
# Extract data from XML and store in a list of dictionaries
data = []
for record in soup.find_all("record"):
    record_data = {}
    for field in record.find_all("field"):
        name = field.get("name")
        value = field.text
        record_data[name] = value
    data.append(record_data)

# Convert list of dictionaries into DataFrame
popd3_df = pd.DataFrame(data)

popd3_df.head()
# Out:
#   Country or Area               Item  Year  Value
# 0           Aruba  Population, total  1960  54211
# 1           Aruba  Population, total  1961  55438
# 2           Aruba  Population, total  1962  56225
# 3           Aruba  Population, total  1963  56695
# 4           Aruba  Population, total  1964  57032

# %% [markdown]
# MISSING VALUE

# %%
population_xml_check_missing = population_xml.isnull().sum()

print("Mengecek data yang hilang\n")
print(population_xml_check_missing)
# Out:
# Mengecek data yang hilang
#
# record    0
# dtype: int64

# %% [markdown]
# PENYESUAIAN TIPE DATA

# %%
import xml.etree.ElementTree as ET
import pandas as pd

# %%
# Membaca file XML
tree = ET.parse('E:\DE-Mini-Project\data_source\population_data.xml')
root = tree.getroot()

# %%
# Inisialisasi list kosong untuk menyimpan data
data = []

# %%
# Loop melalui elemen-elemen dalam file XML
for country in root.findall('country'):
    year = int(country.find('year').text)
    
    # Memasukkan data ke dalam list
    data.append({'year': year})

# %%
# Membuat DataFrame dari list data
population_xml = pd.DataFrame(data)

# Menampilkan informasi tipe data setelah penyesuaian
population_xml.dtypes
# Out:
# Series([], dtype: object)

# %% [markdown]
# CLEANING DATA

# %%
population_xml_cleaned = population_xml.dropna(axis=1, how='all')

print("Setelah mengecek data yang hilang")
print(population_xml_cleaned)
# Out:
# Setelah mengecek data yang hilang
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# DUMMY VARIABLES

# %%
# import required modules
import pandas as pd
import numpy as np
 
# create dataset
population_xml = pd.DataFrame({'Year': ['1960', '1961', '1962'],
                   })
 
# display dataset
print(population_xml)
 
# create dummy variables
pd.get_dummies(population_xml)
# Out:
#    Year
# 0  1960
# 1  1961
# 2  1962
#    Year_1960  Year_1961  Year_1962
# 0       True      False      False
# 1      False       True      False
# 2      False      False       True

# %% [markdown]
# DATA DUPLICATE

# %%
population_xml_duplicate = population_xml_cleaned.drop_duplicates()

print(population_xml_duplicate)

population_xml_duplicate.to_csv("data_clean/population_data.xml", index=False)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# # TRANSFORM

# %%
# Load the data
rural_population = pd.read_csv('data_source/rural_population_percent.csv')
electricity_access = pd.read_csv('data_source/electricity_access_percent.csv')

# %%
rural_population ['Country Name'].tolist()
# From the output, we should be careful for a similar country name, e.g.
# Niger VS Nigeria
# Out:
# ['Aruba',
#  'Afghanistan',
#  'Angola',
#  'Albania',
#  'Andorra',
#  'Arab World',
#  'United Arab Emirates',
#  'Argentina',
#  'Armenia',
#  'American Samoa',
#  'Antigua and Barbuda',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Burundi',
#  'Belgium',
#  'Benin',
#  'Burkina Faso',
#  'Bangladesh',
#  'Bulgaria',
#  'Bahrain',
#  'Bahamas, The',
#  'Bosnia and Herzegovina',
#  'Belarus',
#  'Belize',
#  'Bermuda',
#  'Bolivia',
#  'Brazil',
#  'Barbados',
#  'Brunei Darussalam',
#  'Bhutan',
#  'Botswana',
#  'Central African Republic',
#  'Canada',
#  'Central Europe and the Baltics',
#  'Switzerland',
#  'Channel Islands',
#  'Chile',
#  'China',
#  "Cote d'Ivoire",
#  'Cameroon',
#  'Congo, Dem. Rep.',
#  'Congo, Rep.',
#  'Colombia',
#  'Comoros',
#  'Cabo Verde',
#  'Costa Rica',
#  'Caribbean small states',
#  'Cuba',
#  'Curacao',
#  'Cayman Islands',
#  'Cyprus',
#  'Czech Republic',
#  'Germany',
#  'Djibouti',
#  'Dominica',
#  'Denmark',
# ...

# %%
import pandas as pd

# Assuming you're loading data from a CSV file
df_projects = pd.read_csv('data_source/projects_data.csv')
# Out:
# C:\Users\hello\AppData\Local\Temp\ipykernel_23664\2573015664.py:4: DtypeWarning:
#
# Columns (44) have mixed types. Specify dtype option on import or set low_memory=False.

# %% [markdown]
# MENGGABUNGKAN POPULATION CSV DAN POPULATION JSON

# %%
import pandas as pd

# Make sure the file path and name are correct
population_csv = pd.read_csv('data_source/population_data.csv')

# %%
merge_population_csv_json = population_csv.merge(
    population_csv,
    how='inner',
    on=['Country Name', 'Country Code']
)

# %%
print(population_csv.columns)
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', 'Unnamed: 62'],
#       dtype='object')

# %%
print(population_json.columns)
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017'],
#       dtype='object')

# %%
population_csv.update(population_json[population_json['Country Name'].isin(population_csv['Country Name'])])

# %% [markdown]
# CLEANING COUNTRYNAME

# %%
df_projects.head()
# Out:
#         id  regionname                                        countryname  \
# 0  P162228       Other                                        World;World
# 1  P163962      Africa  Democratic Republic of the Congo;Democratic Re...
# 2  P167672  South Asia  People's Republic of Bangladesh;People's Repub...
# 3  P158768  South Asia  Islamic  Republic of Afghanistan;Islamic  Repu...
# 4  P161364      Africa  Federal Republic of Nigeria;Federal Republic o...
#
#   prodline                  lendinginstr lendinginstrtype  \
# 0       RE  Investment Project Financing               IN
# 1       PE  Investment Project Financing               IN
# 2       PE  Investment Project Financing               IN
# 3       PE  Investment Project Financing               IN
# 4       PE  Investment Project Financing               IN
#
#   envassesmentcategorycode supplementprojectflg productlinetype  \
# 0                        C                    N               L
# ...

# %%
df_projects[[
    'id', 'regionname', 'countryname', 'lendinginstr', 'lendprojectcost'
]]
# Out:
#             id                   regionname  \
# 0      P162228                        Other
# 1      P163962                       Africa
# 2      P167672                   South Asia
# 3      P158768                   South Asia
# 4      P161364                       Africa
# ...        ...                          ...
# 18243  P006578  Latin America and Caribbean
# 18244  P037451      Europe and Central Asia
# 18245  P037362      Europe and Central Asia
# 18246  P037452      Europe and Central Asia
# 18247  P037383      Europe and Central Asia
#
#                                              countryname  \
# 0                                            World;World
# 1      Democratic Republic of the Congo;Democratic Re...
# 2      People's Republic of Bangladesh;People's Repub...
# 3      Islamic  Republic of Afghanistan;Islamic  Repu...
# 4      Federal Republic of Nigeria;Federal Republic o...
# ...                                                  ...
# ...

# %%
df_projects['lendprojectcost'] = df_projects['lendprojectcost'].str.replace(',', '').astype(float)

# %%
df_projects[[
    'id', 'regionname', 'countryname', 'lendinginstr', 'lendprojectcost'
]].describe()
# Out:
#        lendprojectcost
# count     1.812300e+04
# mean      1.348273e+08
# std       1.134161e+09
# min       0.000000e+00
# 25%       9.000000e+06
# 50%       3.000000e+07
# 75%       9.800000e+07
# max       9.300700e+10

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.4; however, version 24.0 is available.
# You should consider upgrading via the 'C:\Users\hello\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import seaborn as sns

# %%
pip install matplotlib
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.4; however, version 24.0 is available.
# You should consider upgrading via the 'C:\Users\hello\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.
# ...

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # KOMBINASI

# %%
import pandas as pd
pd.options.mode.copy_on_write = True

# %% [markdown]
# MERGE 1

# %% [markdown]
# population_csv

# %%
population_csv = pd.read_csv('data_source/population_data.csv')
population_csv
# Out:
#      Country Name Country Code     Indicator Name Indicator Code        1960  \
# 0           Aruba          ABW  Population, total    SP.POP.TOTL     54211.0
# 1     Afghanistan          AFG  Population, total    SP.POP.TOTL   8996351.0
# 2          Angola          AGO  Population, total    SP.POP.TOTL   5643182.0
# 3         Albania          ALB  Population, total    SP.POP.TOTL   1608800.0
# 4         Andorra          AND  Population, total    SP.POP.TOTL     13411.0
# ..            ...          ...                ...            ...         ...
# 259        Kosovo          XKX  Population, total    SP.POP.TOTL    947000.0
# 260   Yemen, Rep.          YEM  Population, total    SP.POP.TOTL   5172135.0
# 261  South Africa          ZAF  Population, total    SP.POP.TOTL  17456855.0
# 262        Zambia          ZMB  Population, total    SP.POP.TOTL   3044846.0
# 263      Zimbabwe          ZWE  Population, total    SP.POP.TOTL   3747369.0
#
# ...

# %%
population_csv_cleaned = population_csv.dropna(axis=1, how='all')
print("Setelah mengecek data yang hilang")
print(population_csv_cleaned)
# Out:
# Setelah mengecek data yang hilang
#      Country Name Country Code     Indicator Name Indicator Code        1960  \
# 0           Aruba          ABW  Population, total    SP.POP.TOTL     54211.0
# 1     Afghanistan          AFG  Population, total    SP.POP.TOTL   8996351.0
# 2          Angola          AGO  Population, total    SP.POP.TOTL   5643182.0
# 3         Albania          ALB  Population, total    SP.POP.TOTL   1608800.0
# 4         Andorra          AND  Population, total    SP.POP.TOTL     13411.0
# ..            ...          ...                ...            ...         ...
# 259        Kosovo          XKX  Population, total    SP.POP.TOTL    947000.0
# 260   Yemen, Rep.          YEM  Population, total    SP.POP.TOTL   5172135.0
# 261  South Africa          ZAF  Population, total    SP.POP.TOTL  17456855.0
# 262        Zambia          ZMB  Population, total    SP.POP.TOTL   3044846.0
# 263      Zimbabwe          ZWE  Population, total    SP.POP.TOTL   3747369.0
#
# ...

# %%
# %restart
# Out:
# UsageError: Line magic function `%restart` not found.

# %%
def clean_columns(population_csv):
    columns_to_remove = ['index','Unnamed', 'Indicator Name', 'Indicator Code']
    return population_csv.loc[:, ~population_csv.columns.str.contains('|'.join(columns_to_remove))]

# %%
population_csv = clean_columns(population_csv)
population_csv
# Out:
#      Country Name Country Code        1960        1961        1962  \
# 0           Aruba          ABW     54211.0     55438.0     56225.0
# 1     Afghanistan          AFG   8996351.0   9166764.0   9345868.0
# 2          Angola          AGO   5643182.0   5753024.0   5866061.0
# 3         Albania          ALB   1608800.0   1659800.0   1711319.0
# 4         Andorra          AND     13411.0     14375.0     15370.0
# ..            ...          ...         ...         ...         ...
# 259        Kosovo          XKX    947000.0    966000.0    994000.0
# 260   Yemen, Rep.          YEM   5172135.0   5260501.0   5351799.0
# 261  South Africa          ZAF  17456855.0  17920673.0  18401608.0
# 262        Zambia          ZMB   3044846.0   3140264.0   3240587.0
# 263      Zimbabwe          ZWE   3747369.0   3870756.0   3999419.0
#
#            1963        1964        1965        1966        1967  ...  \
# 0       56695.0     57032.0     57360.0     57715.0     58055.0  ...
# ...

# %%
population_csv = pd.melt(population_csv, id_vars=['Country Name', 'Country Code'], var_name='Year', value_name='Population')

# %%
population_csv
# Out:
#        Country Name Country Code  Year  Population
# 0             Aruba          ABW  1960     54211.0
# 1       Afghanistan          AFG  1960   8996351.0
# 2            Angola          AGO  1960   5643182.0
# 3           Albania          ALB  1960   1608800.0
# 4           Andorra          AND  1960     13411.0
# ...             ...          ...   ...         ...
# 15307        Kosovo          XKX  2017   1830700.0
# 15308   Yemen, Rep.          YEM  2017  28250420.0
# 15309  South Africa          ZAF  2017  56717156.0
# 15310        Zambia          ZMB  2017  17094130.0
# 15311      Zimbabwe          ZWE  2017  16529904.0
#
# [15312 rows x 4 columns]

# %% [markdown]
# GDP

# %%
gdp_data = pd.read_csv('data_source/gdp_data.csv')
gdp_data
# Out:
#      Country Name Country Code     Indicator Name  Indicator Code  \
# 0           Aruba          ABW  GDP (current US$)  NY.GDP.MKTP.CD
# 1     Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD
# 2          Angola          AGO  GDP (current US$)  NY.GDP.MKTP.CD
# 3         Albania          ALB  GDP (current US$)  NY.GDP.MKTP.CD
# 4         Andorra          AND  GDP (current US$)  NY.GDP.MKTP.CD
# ..            ...          ...                ...             ...
# 259        Kosovo          XKX  GDP (current US$)  NY.GDP.MKTP.CD
# 260   Yemen, Rep.          YEM  GDP (current US$)  NY.GDP.MKTP.CD
# 261  South Africa          ZAF  GDP (current US$)  NY.GDP.MKTP.CD
# 262        Zambia          ZMB  GDP (current US$)  NY.GDP.MKTP.CD
# 263      Zimbabwe          ZWE  GDP (current US$)  NY.GDP.MKTP.CD
#
#              1960          1961          1962          1963          1964  \
# 0             NaN           NaN           NaN           NaN           NaN
# ...

# %%
gdp_data_cleaned = gdp_data.dropna(axis=1, how='all')

print("Setelah mengecek data yang hilang")
print(gdp_data_cleaned)
# Out:
# Setelah mengecek data yang hilang
#      Country Name Country Code     Indicator Name  Indicator Code  \
# 0           Aruba          ABW  GDP (current US$)  NY.GDP.MKTP.CD
# 1     Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD
# 2          Angola          AGO  GDP (current US$)  NY.GDP.MKTP.CD
# 3         Albania          ALB  GDP (current US$)  NY.GDP.MKTP.CD
# 4         Andorra          AND  GDP (current US$)  NY.GDP.MKTP.CD
# ..            ...          ...                ...             ...
# 259        Kosovo          XKX  GDP (current US$)  NY.GDP.MKTP.CD
# 260   Yemen, Rep.          YEM  GDP (current US$)  NY.GDP.MKTP.CD
# 261  South Africa          ZAF  GDP (current US$)  NY.GDP.MKTP.CD
# 262        Zambia          ZMB  GDP (current US$)  NY.GDP.MKTP.CD
# 263      Zimbabwe          ZWE  GDP (current US$)  NY.GDP.MKTP.CD
#
#              1960          1961          1962          1963          1964  \
# ...

# %%
# %restart
# Out:
# UsageError: Line magic function `%restart` not found.

# %%
def clean_columns(gdp_data):
    columns_to_remove = ['index','Unnamed', 'Indicator Name', 'Indicator Code']
    return gdp_data.loc[:, ~gdp_data.columns.str.contains('|'.join(columns_to_remove))]

# %%
gdp_data = clean_columns(gdp_data)
gdp_data
# Out:
#      Country Name Country Code          1960          1961          1962  \
# 0           Aruba          ABW           NaN           NaN           NaN
# 1     Afghanistan          AFG  5.377778e+08  5.488889e+08  5.466667e+08
# 2          Angola          AGO           NaN           NaN           NaN
# 3         Albania          ALB           NaN           NaN           NaN
# 4         Andorra          AND           NaN           NaN           NaN
# ..            ...          ...           ...           ...           ...
# 259        Kosovo          XKX           NaN           NaN           NaN
# 260   Yemen, Rep.          YEM           NaN           NaN           NaN
# 261  South Africa          ZAF  7.575248e+09  7.972841e+09  8.497830e+09
# 262        Zambia          ZMB  7.130000e+08  6.962857e+08  6.931429e+08
# 263      Zimbabwe          ZWE  1.052990e+09  1.096647e+09  1.117602e+09
#
#              1963          1964          1965          1966          1967  \
# ...

# %%
gdp_data = pd.melt(gdp_data, id_vars=['Country Name', 'Country Code'], var_name='Year', value_name='GDP')

# %%
gdp_data
# Out:
#        Country Name Country Code  Year           GDP
# 0             Aruba          ABW  1960           NaN
# 1       Afghanistan          AFG  1960  5.377778e+08
# 2            Angola          AGO  1960           NaN
# 3           Albania          ALB  1960           NaN
# 4           Andorra          AND  1960           NaN
# ...             ...          ...   ...           ...
# 15307        Kosovo          XKX  2017  7.128691e+09
# 15308   Yemen, Rep.          YEM  2017           NaN
# 15309  South Africa          ZAF  2017  3.494193e+11
# 15310        Zambia          ZMB  2017  2.580867e+10
# 15311      Zimbabwe          ZWE  2017  1.784582e+10
#
# [15312 rows x 4 columns]

# %% [markdown]
# MERGE 2

# %% [markdown]
# RURAL

# %%
rural = pd.read_csv('data_source/rural_population_percent.csv')
rural
# Out:
#      Country Name Country Code                            Indicator Name  \
# 0           Aruba          ABW  Rural population (% of total population)
# 1     Afghanistan          AFG  Rural population (% of total population)
# 2          Angola          AGO  Rural population (% of total population)
# 3         Albania          ALB  Rural population (% of total population)
# 4         Andorra          AND  Rural population (% of total population)
# ..            ...          ...                                       ...
# 259        Kosovo          XKX  Rural population (% of total population)
# 260   Yemen, Rep.          YEM  Rural population (% of total population)
# 261  South Africa          ZAF  Rural population (% of total population)
# 262        Zambia          ZMB  Rural population (% of total population)
# 263      Zimbabwe          ZWE  Rural population (% of total population)
#
#      Indicator Code    1960    1961    1962    1963    1964    1965  ...  \
# ...

# %%
rural_cleaned = gdp_data.dropna(axis=1, how='all')

print("Setelah mengecek data yang hilang")
print(rural_cleaned)
# Out:
# Setelah mengecek data yang hilang
#        Country Name Country Code  Year           GDP
# 0             Aruba          ABW  1960           NaN
# 1       Afghanistan          AFG  1960  5.377778e+08
# 2            Angola          AGO  1960           NaN
# 3           Albania          ALB  1960           NaN
# 4           Andorra          AND  1960           NaN
# ...             ...          ...   ...           ...
# 15307        Kosovo          XKX  2017  7.128691e+09
# 15308   Yemen, Rep.          YEM  2017           NaN
# 15309  South Africa          ZAF  2017  3.494193e+11
# 15310        Zambia          ZMB  2017  2.580867e+10
# 15311      Zimbabwe          ZWE  2017  1.784582e+10
#
# [15312 rows x 4 columns]

# %%
def clean_columns(rural):
    columns_to_remove = ['index','Unnamed', 'Indicator Name', 'Indicator Code']
    return rural.loc[:, ~rural.columns.str.contains('|'.join(columns_to_remove))]

# %%
rural = clean_columns(rural)
rural
# Out:
#      Country Name Country Code    1960    1961    1962    1963    1964  \
# 0           Aruba          ABW  49.224  49.239  49.254  49.270  49.285
# 1     Afghanistan          AFG  91.779  91.492  91.195  90.890  90.574
# 2          Angola          AGO  89.565  89.202  88.796  88.376  87.942
# 3         Albania          ALB  69.295  69.057  68.985  68.914  68.842
# 4         Andorra          AND  41.550  39.017  36.538  34.128  31.795
# ..            ...          ...     ...     ...     ...     ...     ...
# 259        Kosovo          XKX     NaN     NaN     NaN     NaN     NaN
# 260   Yemen, Rep.          YEM  90.900  90.541  90.169  89.784  89.386
# 261  South Africa          ZAF  53.381  53.207  53.094  52.980  52.866
# 262        Zambia          ZMB  81.855  81.049  80.215  79.288  77.985
# 263      Zimbabwe          ZWE  87.392  87.179  86.918  86.422  85.908
#
#        1965    1966    1967  ...    2008    2009    2010    2011    2012  \
# ...

# %%
rural = pd.melt(rural, id_vars=['Country Name', 'Country Code'], var_name='Year', value_name='rural')

# %%
rural
# Out:
#        Country Name Country Code  Year   rural
# 0             Aruba          ABW  1960  49.224
# 1       Afghanistan          AFG  1960  91.779
# 2            Angola          AGO  1960  89.565
# 3           Albania          ALB  1960  69.295
# 4           Andorra          AND  1960  41.550
# ...             ...          ...   ...     ...
# 15307        Kosovo          XKX  2017     NaN
# 15308   Yemen, Rep.          YEM  2017  64.231
# 15309  South Africa          ZAF  2017  34.218
# 15310        Zambia          ZMB  2017  58.160
# 15311      Zimbabwe          ZWE  2017  67.793
#
# [15312 rows x 4 columns]

# %% [markdown]
# Electricity

# %%
electricity = pd.read_csv('data_source/electricity_access_percent.csv')
electricity.head()
# Out:
#   Country Name Country Code                           Indicator Name  \
# 0        Aruba          ABW  Access to electricity (% of population)
# 1  Afghanistan          AFG  Access to electricity (% of population)
# 2       Angola          AGO  Access to electricity (% of population)
# 3      Albania          ALB  Access to electricity (% of population)
# 4      Andorra          AND  Access to electricity (% of population)
#
#    Indicator Code  1960  1961  1962  1963  1964  1965  ...        2009  \
# 0  EG.ELC.ACCS.ZS   NaN   NaN   NaN   NaN   NaN   NaN  ...   93.354546
# 1  EG.ELC.ACCS.ZS   NaN   NaN   NaN   NaN   NaN   NaN  ...   44.854885
# 2  EG.ELC.ACCS.ZS   NaN   NaN   NaN   NaN   NaN   NaN  ...   32.382469
# 3  EG.ELC.ACCS.ZS   NaN   NaN   NaN   NaN   NaN   NaN  ...  100.000000
# 4  EG.ELC.ACCS.ZS   NaN   NaN   NaN   NaN   NaN   NaN  ...  100.000000
#
#          2010        2011        2012        2013        2014        2015  \
# ...

# %%
electricity_cleaned = gdp_data.dropna(axis=1, how='all')

print("Setelah mengecek data yang hilang")
print(electricity_cleaned)
# Out:
# Setelah mengecek data yang hilang
#        Country Name Country Code  Year           GDP
# 0             Aruba          ABW  1960           NaN
# 1       Afghanistan          AFG  1960  5.377778e+08
# 2            Angola          AGO  1960           NaN
# 3           Albania          ALB  1960           NaN
# 4           Andorra          AND  1960           NaN
# ...             ...          ...   ...           ...
# 15307        Kosovo          XKX  2017  7.128691e+09
# 15308   Yemen, Rep.          YEM  2017           NaN
# 15309  South Africa          ZAF  2017  3.494193e+11
# 15310        Zambia          ZMB  2017  2.580867e+10
# 15311      Zimbabwe          ZWE  2017  1.784582e+10
#
# [15312 rows x 4 columns]

# %%
def clean_columns(electricity):
    columns_to_remove = ['index','Unnamed', 'Indicator Name', 'Indicator Code']
    return electricity.loc[:, ~electricity.columns.str.contains('|'.join(columns_to_remove))]

# %%
electricity = clean_columns(electricity)
electricity
# Out:
#      Country Name Country Code  1960  1961  1962  1963  1964  1965  1966  \
# 0           Aruba          ABW   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1     Afghanistan          AFG   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2          Angola          AGO   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3         Albania          ALB   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4         Andorra          AND   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ..            ...          ...   ...   ...   ...   ...   ...   ...   ...
# 259        Kosovo          XKX   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 260   Yemen, Rep.          YEM   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 261  South Africa          ZAF   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 262        Zambia          ZMB   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 263      Zimbabwe          ZWE   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#      1967  ...        2008        2009        2010        2011        2012  \
# ...

# %%
electricity = pd.melt(electricity, id_vars=['Country Name', 'Country Code'], var_name='Year', value_name='electricity')

# %%
electricity
# Out:
#        Country Name Country Code  Year  electricity
# 0             Aruba          ABW  1960          NaN
# 1       Afghanistan          AFG  1960          NaN
# 2            Angola          AGO  1960          NaN
# 3           Albania          ALB  1960          NaN
# 4           Andorra          AND  1960          NaN
# ...             ...          ...   ...          ...
# 15307        Kosovo          XKX  2017          NaN
# 15308   Yemen, Rep.          YEM  2017          NaN
# 15309  South Africa          ZAF  2017          NaN
# 15310        Zambia          ZMB  2017          NaN
# 15311      Zimbabwe          ZWE  2017          NaN
#
# [15312 rows x 4 columns]

# %% [markdown]
# # PENGGABUNGAN MERGE

# %%
merge_data = pd.merge(population_csv, gdp_data, on =['Country Name', 'Country Code', 'Year'])
merge_data_2 = pd.merge(rural, electricity, on =['Country Name', 'Country Code', 'Year'])

combine_data = pd.merge(merge_data, merge_data_2, on =['Country Name', 'Country Code', 'Year'])

# %%
merge_data
# Out:
#        Country Name Country Code  Year  Population           GDP
# 0             Aruba          ABW  1960     54211.0           NaN
# 1       Afghanistan          AFG  1960   8996351.0  5.377778e+08
# 2            Angola          AGO  1960   5643182.0           NaN
# 3           Albania          ALB  1960   1608800.0           NaN
# 4           Andorra          AND  1960     13411.0           NaN
# ...             ...          ...   ...         ...           ...
# 15307        Kosovo          XKX  2017   1830700.0  7.128691e+09
# 15308   Yemen, Rep.          YEM  2017  28250420.0           NaN
# 15309  South Africa          ZAF  2017  56717156.0  3.494193e+11
# 15310        Zambia          ZMB  2017  17094130.0  2.580867e+10
# 15311      Zimbabwe          ZWE  2017  16529904.0  1.784582e+10
#
# [15312 rows x 5 columns]

# %%
merge_data_2
# Out:
#        Country Name Country Code  Year   rural  electricity
# 0             Aruba          ABW  1960  49.224          NaN
# 1       Afghanistan          AFG  1960  91.779          NaN
# 2            Angola          AGO  1960  89.565          NaN
# 3           Albania          ALB  1960  69.295          NaN
# 4           Andorra          AND  1960  41.550          NaN
# ...             ...          ...   ...     ...          ...
# 15307        Kosovo          XKX  2017     NaN          NaN
# 15308   Yemen, Rep.          YEM  2017  64.231          NaN
# 15309  South Africa          ZAF  2017  34.218          NaN
# 15310        Zambia          ZMB  2017  58.160          NaN
# 15311      Zimbabwe          ZWE  2017  67.793          NaN
#
# [15312 rows x 5 columns]

# %%
combine_data
# Out:
#        Country Name Country Code  Year  Population           GDP   rural  \
# 0             Aruba          ABW  1960     54211.0           NaN  49.224
# 1       Afghanistan          AFG  1960   8996351.0  5.377778e+08  91.779
# 2            Angola          AGO  1960   5643182.0           NaN  89.565
# 3           Albania          ALB  1960   1608800.0           NaN  69.295
# 4           Andorra          AND  1960     13411.0           NaN  41.550
# ...             ...          ...   ...         ...           ...     ...
# 15307        Kosovo          XKX  2017   1830700.0  7.128691e+09     NaN
# 15308   Yemen, Rep.          YEM  2017  28250420.0           NaN  64.231
# 15309  South Africa          ZAF  2017  56717156.0  3.494193e+11  34.218
# 15310        Zambia          ZMB  2017  17094130.0  2.580867e+10  58.160
# 15311      Zimbabwe          ZWE  2017  16529904.0  1.784582e+10  67.793
#
#        electricity
# 0              NaN
# 1              NaN
# 2              NaN
# ...

# %%
combine_data.fillna(0, inplace=True)

# %%
combine_data
# Out:
#        Country Name Country Code  Year  Population           GDP   rural  \
# 0             Aruba          ABW  1960     54211.0  0.000000e+00  49.224
# 1       Afghanistan          AFG  1960   8996351.0  5.377778e+08  91.779
# 2            Angola          AGO  1960   5643182.0  0.000000e+00  89.565
# 3           Albania          ALB  1960   1608800.0  0.000000e+00  69.295
# 4           Andorra          AND  1960     13411.0  0.000000e+00  41.550
# ...             ...          ...   ...         ...           ...     ...
# 15307        Kosovo          XKX  2017   1830700.0  7.128691e+09   0.000
# 15308   Yemen, Rep.          YEM  2017  28250420.0  0.000000e+00  64.231
# 15309  South Africa          ZAF  2017  56717156.0  3.494193e+11  34.218
# 15310        Zambia          ZMB  2017  17094130.0  2.580867e+10  58.160
# 15311      Zimbabwe          ZWE  2017  16529904.0  1.784582e+10  67.793
#
#        electricity
# 0              0.0
# 1              0.0
# 2              0.0
# ...

# %%
# Tambahkan kolom baru gdppercapita
combine_data['gdppercapita'] = combine_data['GDP'] / combine_data['Population']

combine_data
# Out:
#        Country Name Country Code  Year  Population           GDP   rural  \
# 0             Aruba          ABW  1960     54211.0  0.000000e+00  49.224
# 1       Afghanistan          AFG  1960   8996351.0  5.377778e+08  91.779
# 2            Angola          AGO  1960   5643182.0  0.000000e+00  89.565
# 3           Albania          ALB  1960   1608800.0  0.000000e+00  69.295
# 4           Andorra          AND  1960     13411.0  0.000000e+00  41.550
# ...             ...          ...   ...         ...           ...     ...
# 15307        Kosovo          XKX  2017   1830700.0  7.128691e+09   0.000
# 15308   Yemen, Rep.          YEM  2017  28250420.0  0.000000e+00  64.231
# 15309  South Africa          ZAF  2017  56717156.0  3.494193e+11  34.218
# 15310        Zambia          ZMB  2017  17094130.0  2.580867e+10  58.160
# 15311      Zimbabwe          ZWE  2017  16529904.0  1.784582e+10  67.793
#
#        electricity  gdppercapita
# 0              0.0      0.000000
# ...

# %%
combine_data = combine_data.rename(columns={'Country Name': 'countryname', 'Country Code': 'countrycode', 'Year': 'year', 'Population': 'population', 'GDP': 'gdp', 'rural': 'ruralpopulationpercent', 'electricity': 'electricityaccesspercent'})
combine_data
# Out:
#         countryname countrycode  year  population           gdp  \
# 0             Aruba         ABW  1960     54211.0  0.000000e+00
# 1       Afghanistan         AFG  1960   8996351.0  5.377778e+08
# 2            Angola         AGO  1960   5643182.0  0.000000e+00
# 3           Albania         ALB  1960   1608800.0  0.000000e+00
# 4           Andorra         AND  1960     13411.0  0.000000e+00
# ...             ...         ...   ...         ...           ...
# 15307        Kosovo         XKX  2017   1830700.0  7.128691e+09
# 15308   Yemen, Rep.         YEM  2017  28250420.0  0.000000e+00
# 15309  South Africa         ZAF  2017  56717156.0  3.494193e+11
# 15310        Zambia         ZMB  2017  17094130.0  2.580867e+10
# 15311      Zimbabwe         ZWE  2017  16529904.0  1.784582e+10
#
#        ruralpopulationpercent  electricityaccesspercent  gdppercapita
# 0                      49.224                       0.0      0.000000
# ...

# %%
combine_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15312 entries, 0 to 15311
# Data columns (total 8 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   countryname               15312 non-null  object
#  1   countrycode               15312 non-null  object
#  2   year                      15312 non-null  object
#  3   population                15312 non-null  float64
#  4   gdp                       15312 non-null  float64
#  5   ruralpopulationpercent    15312 non-null  float64
#  6   electricityaccesspercent  15312 non-null  float64
#  7   gdppercapita              15150 non-null  float64
# dtypes: float64(5), object(3)
# memory usage: 957.1+ KB

# %% [markdown]
# # OUTLIERS

# %%
# Create the boxplot
sns.boxplot(x='lendprojectcost', data=df_projects)

# Optionally, set a log scale for better visualization
# plt.yscale('log')

# Rotate x-axis labels by 45 degrees
plt.xticks(rotation=60)

# Show the plot
plt.show()

# %%
# Create a histogram to visualize the distribution of 'lendprojectcost'
sns.histplot(df_projects['lendprojectcost'], kde=True)

plt.xlabel('lendprojectcost')
plt.ylabel('Frequency')
plt.title('Distribution of lendprojectcost')

# Show the plot
plt.show()

# %%
(df_projects['lendprojectcost'] == 0).sum()
# Out:
# 150

# %%
# Calculate Q1 (25th percentile) and Q3 (75th percentile)
Q1 = df_projects['lendprojectcost'].quantile(0.25)
Q3 = df_projects['lendprojectcost'].quantile(0.75)

# Calculate the IQR (Interquartile Range)
IQR = Q3 - Q1

# Define lower and upper bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print(f"Q1: {Q1}")
print(f"Q3: {Q3}")
print(f"IQR: {IQR}")
print(f"lower_bound: {lower_bound}")
print(f"upper_bound: {upper_bound}")
# Out:
# Q1: 9000000.0
# Q3: 98000000.0
# IQR: 89000000.0
# lower_bound: -124500000.0
# upper_bound: 231500000.0

# %%
# Create a histogram to visualize the distribution of 'lendprojectcost'
sns.histplot(df_filtered['lendprojectcost'], kde=True)

plt.xlabel('lendprojectcost')
plt.ylabel('Frequency')
plt.title('Distribution of lendprojectcost')

# Show the plot
plt.show()

# %%
(df_filtered['lendprojectcost'] == 0).sum()
# Out:
# 150

# %%
#display(len(
#    df_projects[[
#        'id', 'regionname', 'countryname', 'lendinginstr', 'lendprojectcost'
#    ]]
#))

#display(len(
#    df_projects[[
#        'id', 'regionname', 'countryname', 'lendinginstr', 'lendprojectcost'
#    ]][
#        (df_projects['lendprojectcost'] >= lower_bound)
#        & (df_projects['lendprojectcost'] <= upper_bound)
#    ]
#))

# %%
display(df_projects[[
    'id', 'regionname', 'countryname', 'lendinginstr', 'lendprojectcost'
]].describe())

display(df_filtered[['lendprojectcost']].describe())
# Out:
#              id regionname                          countryname  \
# count     18248      18248                                18248
# unique    18248          7                                  206
# top     P162228     Africa  Republic of India;Republic of India
# freq          1       5710                                  784
#
#                     lendinginstr lendprojectcost
# count                      18002           18123
# unique                        18            4068
# top     Specific Investment Loan      50,000,000
# freq                        7626             368
#        lendprojectcost
# count     1.609200e+04
# mean      4.425228e+07
# std       5.156286e+07
# min       0.000000e+00
# 25%       7.300000e+06
# 50%       2.400000e+07
# 75%       6.000000e+07
# max       2.311000e+08

# %%
# Calculate Q1 (25th percentile) and Q3 (75th percentile)
Q1 = df_filtered['lendprojectcost'].quantile(0.25)
Q3 = df_filtered['lendprojectcost'].quantile(0.75)

# Calculate the IQR (Interquartile Range)
IQR = Q3 - Q1

# Define lower and upper bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print(f"Q1: {Q1}")
print(f"Q3: {Q3}")
print(f"IQR: {IQR}")
print(f"lower_bound: {lower_bound}")
print(f"upper_bound: {upper_bound}")
# Out:
# Q1: 7300000.0
# Q3: 60000000.0
# IQR: 52700000.0
# lower_bound: -71750000.0
# upper_bound: 139050000.0

# %%
# Filter out rows where 'lendprojectcost' falls outside of the bounds
df_filtered_2 = df_filtered[
    (df_filtered['lendprojectcost'] >= lower_bound)
    & (df_filtered['lendprojectcost'] <= upper_bound)
]

# Create the boxplot without outliers
sns.boxplot(x='lendprojectcost', data=df_filtered_2)

# Show the plot
plt.show()

# %%
display(df_filtered[['lendprojectcost']].describe())

display(df_filtered_2[['lendprojectcost']].describe())
# Out:
#        lendprojectcost
# count     1.609200e+04
# mean      4.425228e+07
# std       5.156286e+07
# min       0.000000e+00
# 25%       7.300000e+06
# 50%       2.400000e+07
# 75%       6.000000e+07
# max       2.311000e+08
#        lendprojectcost
# count     1.480400e+04
# mean      3.258506e+07
# std       3.356609e+07
# min       0.000000e+00
# 25%       6.300000e+06
# 50%       2.000000e+07
# 75%       5.000000e+07
# max       1.390000e+08

# %%
display(len(df_filtered))

display(len(
    df_filtered[[
        'id', 'regionname', 'countryname', 'lendinginstr', 'lendprojectcost'
    ]][
        (df_filtered['lendprojectcost'] >= lower_bound)
        & (df_filtered['lendprojectcost'] <= upper_bound)
    ]
))
# Out:
# 16092
# 14804

# %% [markdown]
# # SCALING FEATURES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
# %restart
# Out:
# UsageError: Line magic function `%restart` not found.

# %%
std_scaler = StandardScaler()
scaled_df = combine_data.copy()

scaled_df['gdp_scaled'] = std_scaler.fit_transform(scaled_df[['gdp']])
scaled_df['population_scaled'] = std_scaler.fit_transform(scaled_df[['population']])
scaled_df['ruralpopulation_scaled'] = std_scaler.fit_transform(scaled_df[['ruralpopulationpercent']])
scaled_df['electricityaccess_scaled'] = std_scaler.fit_transform(scaled_df[['electricityaccesspercent']])

clm = ['gdp_scaled', 'population_scaled', 'ruralpopulation_scaled', 'electricityaccess_scaled']
scaled_df = scaled_df[clm]

# %%
scaled_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15312 entries, 0 to 15311
# Data columns (total 4 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   gdp_scaled                15312 non-null  float64
#  1   population_scaled         15312 non-null  float64
#  2   ruralpopulation_scaled    15312 non-null  float64
#  3   electricityaccess_scaled  15312 non-null  float64
# dtypes: float64(4)
# memory usage: 478.6 KB

# %%
scaled_df
# Out:
#        gdp_scaled  population_scaled  ruralpopulation_scaled  \
# 0       -0.192780          -0.301449               -0.030482
# 1       -0.192649          -0.288219                1.635676
# 2       -0.192780          -0.293180                1.548991
# 3       -0.192780          -0.299149                0.755359
# 4       -0.192780          -0.301509               -0.330942
# ...           ...                ...                     ...
# 15307   -0.191049          -0.298820               -1.957751
# 15308   -0.192780          -0.259734                0.557088
# 15309   -0.107954          -0.217619               -0.618012
# 15310   -0.186514          -0.276239                0.319390
# 15311   -0.188448          -0.277074                0.696551
#
#        electricityaccess_scaled
# 0                     -0.786718
# 1                     -0.786718
# 2                     -0.786718
# 3                     -0.786718
# 4                     -0.786718
# ...                         ...
# ...

# %% [markdown]
# FEATURE ENGINEERING

# %%
import pandas as pd

# %%
df_projects = pd.read_csv('data_source/projects_data.csv')
# Out:
# C:\Users\hello\AppData\Local\Temp\ipykernel_23664\3574714880.py:1: DtypeWarning:
#
# Columns (44) have mixed types. Specify dtype option on import or set low_memory=False.

# %%
df_projects[' '] = df_projects['id'] = ' ' + df_projects['countryname'] + ' ' + df_projects['countryname']
df_projects[['id', 'countryname']]
# Out:
#                                                       id  \
# 0                                World;World World;World
# 1       Democratic Republic of the Congo;Democratic R...
# 2       People's Republic of Bangladesh;People's Repu...
# 3       Islamic  Republic of Afghanistan;Islamic  Rep...
# 4       Federal Republic of Nigeria;Federal Republic ...
# ...                                                  ...
# 18243   Republic of Chile;Republic of Chile Republic ...
# 18244   Grand Duchy of Luxembourg;Grand Duchy of Luxe...
# 18245   Kingdom of Denmark;Kingdom of Denmark Kingdom...
# 18246   Kingdom of the Netherlands;Kingdom of the Net...
# 18247   French Republic;French Republic French Republ...
#
#                                              countryname
# 0                                            World;World
# 1      Democratic Republic of the Congo;Democratic Re...
# 2      People's Republic of Bangladesh;People's Repub...
# ...

# %% [markdown]
# # LOAD

# %% [markdown]
# # DATA VISUALIZATION

# %%
import pandas as pd

# Memuat data
df_projects = pd.read_csv('data_source/projects_data.csv')

# Menampilkan lima baris pertama dari dataset
print(df_projects.head())
# Out:
#         id  regionname                                        countryname  \
# 0  P162228       Other                                        World;World
# 1  P163962      Africa  Democratic Republic of the Congo;Democratic Re...
# 2  P167672  South Asia  People's Republic of Bangladesh;People's Repub...
# 3  P158768  South Asia  Islamic  Republic of Afghanistan;Islamic  Repu...
# 4  P161364      Africa  Federal Republic of Nigeria;Federal Republic o...
#
#   prodline                  lendinginstr lendinginstrtype  \
# 0       RE  Investment Project Financing               IN
# 1       PE  Investment Project Financing               IN
# 2       PE  Investment Project Financing               IN
# 3       PE  Investment Project Financing               IN
# 4       PE  Investment Project Financing               IN
#
#   envassesmentcategorycode supplementprojectflg productlinetype  \
# 0                        C                    N               L
# ...

# %%
pip install nbformat --upgrade
# Out:
# ...
# WARNING: You are using pip version 21.2.4; however, version 24.0 is available.
# You should consider upgrading via the 'C:\Users\hello\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Memuat data
df_projects = pd.read_csv('data_source/projects_data.csv')

# Menampilkan lima baris pertama dari dataset
df_projects.head()
# Out:
# C:\Users\hello\AppData\Local\Temp\ipykernel_23664\104801177.py:2: DtypeWarning:
#
# Columns (44) have mixed types. Specify dtype option on import or set low_memory=False.
#         id  regionname                                        countryname  \
# 0  P162228       Other                                        World;World
# 1  P163962      Africa  Democratic Republic of the Congo;Democratic Re...
# 2  P167672  South Asia  People's Republic of Bangladesh;People's Repub...
# 3  P158768  South Asia  Islamic  Republic of Afghanistan;Islamic  Repu...
# 4  P161364      Africa  Federal Republic of Nigeria;Federal Republic o...
#
#   prodline                  lendinginstr lendinginstrtype  \
# 0       RE  Investment Project Financing               IN
# 1       PE  Investment Project Financing               IN
# 2       PE  Investment Project Financing               IN
# 3       PE  Investment Project Financing               IN
# 4       PE  Investment Project Financing               IN
#
# ...

# %%
pip install nbformat --upgrade
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.4; however, version 24.0 is available.
# You should consider upgrading via the 'C:\Users\hello\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
pip install nbformat --upgrade
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.4; however, version 24.0 is available.
# You should consider upgrading via the 'C:\Users\hello\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Memuat data
df_projects = pd.read_csv('data_source/projects_data.csv')

# Visualisasi distribusi biaya proyek menggunakan seaborn
plt.figure(figsize=(10, 6))
sns.histplot(df_projects['regionname'], kde=True, color='skyblue', edgecolor='black')
plt.title('Distribution of Lend Project Cost')
plt.xlabel('Lend Project Cost')
plt.ylabel('Frequency')
plt.grid(True)
plt
# Out:
# C:\Users\hello\AppData\Local\Temp\ipykernel_23664\4128233782.py:6: DtypeWarning:
#
# Columns (44) have mixed types. Specify dtype option on import or set low_memory=False.
# <module 'matplotlib.pyplot' from 'C:\\Users\\hello\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Memuat data
df_projects = pd.read_csv('data_source/projects_data.csv')

# Analisis Korelasi
plt.figure(figsize=(10, 8))
sns.heatmap(scaled_df.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# Analisis Tren
# Mengubah kolom regionname ke tipe datetime
df_projects['regionname'] = pd.to_datetime(df_projects['regionname'])

# Ekstrak tahun dari boardapprovaldate
df_projects['year'] = df_projects['regionname'].dt.year

# Hitung jumlah proyek per tahun
projects_per_year = df_projects['year'].value_counts().sort_index()

# Visualisasi tren jumlah proyek dari tahun ke tahun
plt.figure(figsize=(10, 6))
sns.lineplot(x=projects_per_year.index, y=projects_per_year.values, marker='o')
plt.title('Trend of Number of Projects Over Years')
plt.xlabel('Year')
plt.ylabel('Number of Projects')
plt.grid(True)
plt
# Out:
# C:\Users\hello\AppData\Local\Temp\ipykernel_23664\3190477225.py:6: DtypeWarning:
#
# Columns (44) have mixed types. Specify dtype option on import or set low_memory=False.
# C:\Users\hello\AppData\Local\Temp\ipykernel_23664\3190477225.py:16: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# ---------------------------------------------------------------------------
# DateParseError                            Traceback (most recent call last)
# Cell In[504], line 16
#      12 plt.show()
#      14 # Analisis Tren
#      15 # Mengubah kolom regionname ke tipe datetime
# ---> 16 df_projects['regionname'] = pd.to_datetime(df_projects['regionname'])
#      18 # Ekstrak tahun dari boardapprovaldate
#      19 df_projects['year'] = df_projects['regionname'].dt.year
#
# ...

# %%
# Menghitung jumlah proyek berdasarkan tahun
project_count_by_year = df_projects['regionname'].str.slice(0, 4).value_counts().reset_index()
project_count_by_year.columns = ['Region', 'Number of Projects']

# Visualisasi tren jumlah proyek dari tahun ke tahun
plt.figure(figsize=(10, 6))
plt.plot(project_count_by_year['Region'], project_count_by_year['Number of Projects'], marker='o')
plt.title('Trend of Number of Projects Over')
plt.xlabel('Region')
plt.ylabel('Number of Projects')
plt.grid(True)
plt.xticks(rotation=45)
plt.show()

# %%
import matplotlib.pyplot as plt

# Visualisasi distribusi biaya proyek
plt.figure(figsize=(10, 6))
plt.hist(df_projects['regionname'], bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of Lend Project Cost')
plt.xlabel('Lend Project Cost')
plt.ylabel('Frequency')
plt.grid(True)
plt
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\hello\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
pip install dash
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.4; however, version 24.0 is available.
# You should consider upgrading via the 'C:\Users\hello\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.
